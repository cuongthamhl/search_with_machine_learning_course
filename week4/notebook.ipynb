# %% [markdown]
# # Setting up

# %%
import pandas as pd
import json
from functions import display_rows
import sys,os,os.path
import math


# %env WEEK4 /workspace/search_with_machine_learning_course/week4
WEEK4='/workspace/search_with_machine_learning_course/week4'
# Out:
# env: WEEK4=/workspace/search_with_machine_learning_course/week4

# %%
# Dump categories, 10 level deep, dump everything
# !python $WEEK4/dump_category_depth_maps.py --output=/workspace/search_with_machine_learning_course/week4/data/category_parent_maps.csv

category_parent_maps_df = pd.read_csv(f'{WEEK4}/data/category_parent_maps.csv').sort_values(by=['depth'], ascending=True)
category_parent_maps_df
# Out:
# Number of categories: 4625
# Writting data to /workspace/search_with_machine_learning_course/week4/data/category_parent_maps.csv...
#                      id               name           parent_id   parent_name  \
# 0              cat00000           Best Buy                 NaN           NaN
# 27         abcat0100000  TV & Home Theater            cat00000      Best Buy
# 423  pcmcat245100050028             Office            cat00000      Best Buy
# 296        abcat0800000      Mobile Phones            cat00000      Best Buy
# 45         abcat0300000  Car, Marine & GPS            cat00000      Best Buy
# ..                  ...                ...                 ...           ...
# 300        abcat0404002      Compact Flash  pcmcat225800050009  Memory Cards
# 301        abcat0404003       Memory Stick  pcmcat225800050009  Memory Cards
# 302        abcat0404004     Secure Digital  pcmcat225800050009  Memory Cards
# 303        abcat0404005    XD Memory Cards  pcmcat225800050009  Memory Cards
# 304        abcat0404006       Memory Cases  pcmcat225800050009  Memory Cards
#
#      depth
# 0        1
# 27       2
# 423      2
# 296      2
# 45       2
# ..     ...
# 300      8
# 301      8
# 302      8
# 303      8
# 304      8
#
# [4625 rows x 5 columns]

# %%
# normalize user queires, this can take a while
#!python prep_train_csv.py --input=/workspace/datasets/train.csv --output=/workspace/datasets/train_prep_week4.csv
train_df = pd.read_csv('/workspace/datasets/train_prep_week4.csv')

# %%
unique_queries_per_category = train_df.groupby(['category'])['query_normalized'].nunique().reset_index().rename({'query_normalized': 'query_count'}, axis='columns')

display(unique_queries_per_category)

queries_df_with_query_count = pd.merge(train_df, unique_queries_per_category, on='category', how='inner').merge(category_parent_maps_df, left_on='category', right_on='id', how='inner')
       
queries_df_with_query_count.head(5)
# Out:
#                category  query_count
# 0                  None           42
# 1          abcat0011000            6
# 2          abcat0020000            1
# 3          abcat0020004            3
# 4          abcat0031100           33
# ...                 ...          ...
# 1535  pcmcat96200050043           18
# 1536  pcmcat96200050046           58
# 1537  pcmcat96200050047           27
# 1538  pcmcat96200050052            1
# 1539  pcmcat99000050002           12
#
# [1540 rows x 2 columns]
#    Unnamed: 0                                      user      sku  \
# 0           0  000000df17cd56a5df4a94074e133c9d4739fae3  2125233
# 1           1  000001928162247ffaf63185cd8b2a244c78e7c6  2009324
# 2           3  000017f79c2b5da56721f22f9fdd726b13daf8e8  2877125
# 3          19  0000c4e9d7075985d1020c456e7ce36f83f834eb  2126065
# 4          40  00017f7beeac02736c0ce7bf1e75f3010939b34e  1831054
#
#        category                                query  \
# 0  abcat0101001  Televisiones Panasonic  50 pulgadas
# 1  abcat0101001                                Sharp
# 2  abcat0101001                                  rca
# 3  abcat0101001                           Samsung 40
# 4  abcat0101001                               lcd tv
#
#                 query_normalized  query_count            id  \
# 0  television panason 50 pulgada        11437  abcat0101001
# 1                          sharp        11437  abcat0101001
# 2                            rca        11437  abcat0101001
# 3                     samsung 40        11437  abcat0101001
# 4                         lcd tv        11437  abcat0101001
#
#                  name     parent_id parent_name  depth
# 0  All Flat-Panel TVs  abcat0101000         TVs      4
# 1  All Flat-Panel TVs  abcat0101000         TVs      4
# 2  All Flat-Panel TVs  abcat0101000         TVs      4
# 3  All Flat-Panel TVs  abcat0101000         TVs      4
# 4  All Flat-Panel TVs  abcat0101000         TVs      4

# %%
class Node:
    def __init__(self, data):
        self.children = []
        self.data = data

def build_tree():
    cats = category_parent_maps_df
    columns = cats.columns.to_list()
    rows = cats.to_numpy()

    retries = []

    cat_nodes = {}
    root = None

    for row in rows:
        name = row[columns.index('name')] 
        id = row[columns.index('id')] 
        parent_id_raw = row[columns.index('parent_id')] 
        parent_id = None if pd.isna(parent_id_raw) else parent_id_raw
        #print(f'id={id}, name={name}, parent_id={parent_id}')    
        
        count_row = unique_queries_per_category[unique_queries_per_category['category'] == id]
        if count_row.empty:
            count = 0
        else:
            count = count_row.iloc[0]['query_count']

        node = Node({'id': id, 'name': name, 'count': count, 'parent_id': parent_id})
        cat_nodes[id] = node

        if parent_id is None:            
            root = node

    for id, node in cat_nodes.items():    
        
        if node.data['parent_id'] is not None:
            try:
                cat_nodes[node.data['parent_id']].children.append(node)
                
            except KeyError as e:
                print('Parent ID not found: ' + str(e))
    
    return (root, cat_nodes)


def print_node(node: Node, depth):
    print(
        (' . ' * (depth)*2) + 
        (f" |- {node.data['id']} - {node.data['name']} ({node.data['count']})")
    )

def walk(node: Node, depth = 0):
    print_node(node, depth)

    for child in node.children:
        walk(child, depth + 1)

def update_query_count(node: Node, depth = 0):
    if len(node.children) == 0:
        # leaf node
        return node.data['count']

    total_count = 0
    for child in node.children:        
        total_count += update_query_count(child, depth + 1)
    
   
    node.data['count'] = total_count

    return total_count

def try_rollup(node: Node, threshold: int, cat_nodes: dict): 
    
    if node.data['count'] >= threshold:
        #print(f"node.data.count: {node.data['count']}, threshold: {threshold}")   
        return node

    round = 0
    parent_node = node
    while node.data['count'] < threshold:
        if round > 100:
            #infinite loop protection
            print('quiting try_rollup, too many tries...')
            break
        round += 1
        parent_node = cat_nodes[parent_node.data['parent_id']]
        if parent_node.data['count'] >= threshold:
            return parent_node
    
    if parent_node is not None:
        return parent_node
    else:
        return node

        

# if necessary, roll leaf nodes up to the desired node
def build_rollup_map(node: Node, threshold, cat_nodes: dict, rollup_map = {}, depth = 0):
    if len(node.children) == 0:
        roll_to = try_rollup(node, threshold, cat_nodes)
        # leaf node         
        rollup_map[node.data['id']] = {
            'from': node,
            'to': roll_to
        }
    
    for child in node.children:
        verdict = build_rollup_map(child, threshold, cat_nodes, rollup_map, depth + 1)
    
    return rollup_map

(root, cat_nodes) = build_tree()

print('Number of categories processed: ' + str(len(cat_nodes)))


test_node = cat_nodes['pcmcat139900050002']
speaker_node = cat_nodes['pcmcat143200050022']

update_query_count(root)

ROLLUP_IF_LESS_THAN=1000
rollup_maps = build_rollup_map(root, ROLLUP_IF_LESS_THAN, cat_nodes)

rollup_columns = ['from_category_id', 'from_category_name', 'count', 'to_category_id', 'to_category_name']
rollup_data = []
for id, roll in rollup_maps.items():
    rollup_data.append([
        roll['from'].data['id'],
        roll['from'].data['name'],
        roll['from'].data['count'],
        roll['to'].data['id'],
        roll['to'].data['name'],
    ])
    #print(f"from: {roll['from'].data['id']} - {roll['from'].data['name']} ({roll['from'].data['count']})    | to: {roll['to'].data['id']} - {roll['to'].data['name']} ({roll['to'].data['count']})")

rollup_df = pd.DataFrame(rollup_data, columns=rollup_columns)

rollup_df.nunique()
# Out:
# Parent ID not found: 'pcmcat161200050031'
# Parent ID not found: 'pcmcat161200050031'
# Parent ID not found: 'pcmcat161200050031'
# Parent ID not found: 'pcmcat156300050010'
# Parent ID not found: 'pcmcat156300050010'
# Parent ID not found: 'pcmcat156300050010'
# Parent ID not found: 'pcmcat156300050010'
# Parent ID not found: 'pcmcat156300050010'
# Parent ID not found: 'pcmcat245700050019'
# Parent ID not found: 'pcmcat245700050019'
# Parent ID not found: 'pcmcat245700050019'
# Parent ID not found: 'pcmcat245700050019'
# Parent ID not found: 'pcmcat245700050019'
# Parent ID not found: 'pcmcat245700050019'
# Parent ID not found: 'pcmcat220700050008'
# Parent ID not found: 'pcmcat241300050031'
# Parent ID not found: 'pcmcat241300050031'
# Number of categories processed: 4625
# from_category_id      3862
# from_category_name    3174
# count                  419
# to_category_id         163
# to_category_name       162
# dtype: int64

# %%
cat_nodes_plain = {}

for id,node in cat_nodes.items():
    cat_nodes_plain[id] = node.data

with open(WEEK4 + '/data/cat_nodes.py', 'w') as f:
    f.write(repr(cat_nodes_plain))

# %%
import ast 
with open(WEEK4 + '/data/cat_nodes.py') as f:
    cat_nodes2 = ast.literal_eval(f.read())

# %%
cat_nodes2
# Out:
# {'cat00000': {'id': 'cat00000',
#   'name': 'Best Buy',
#   'count': 281692,
#   'parent_id': None},
#  'abcat0100000': {'id': 'abcat0100000',
#   'name': 'TV & Home Theater',
#   'count': 25750,
#   'parent_id': 'cat00000'},
#  'pcmcat245100050028': {'id': 'pcmcat245100050028',
#   'name': 'Office',
#   'count': 8267,
#   'parent_id': 'cat00000'},
#  'abcat0800000': {'id': 'abcat0800000',
#   'name': 'Mobile Phones',
#   'count': 25818,
#   'parent_id': 'cat00000'},
#  'abcat0300000': {'id': 'abcat0300000',
#   'name': 'Car, Marine & GPS',
#   'count': 6805,
#   'parent_id': 'cat00000'},
#  'pcmcat149900050025': {'id': 'pcmcat149900050025',
#   'name': 'Recycling',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'pcmcat133600050011': {'id': 'pcmcat133600050011',
#   'name': 'Online Trade In',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'abcat0600000': {'id': 'abcat0600000',
#   'name': 'Movies & Music',
#   'count': 36601,
#   'parent_id': 'cat00000'},
#  'abcat0200000': {'id': 'abcat0200000',
#   'name': 'Audio & MP3',
#   'count': 41209,
#   'parent_id': 'cat00000'},
#  'pcmcat248000050016': {'id': 'pcmcat248000050016',
#   'name': 'Deal of the Day',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'abcat0700000': {'id': 'abcat0700000',
#   'name': 'Video Games',
#   'count': 9888,
#   'parent_id': 'cat00000'},
#  'pcmcat248700050021': {'id': 'pcmcat248700050021',
#   'name': 'Home',
#   'count': 3703,
#   'parent_id': 'cat00000'},
#  'pcmcat164600050001': {'id': 'pcmcat164600050001',
#   'name': 'Featured Offers',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'pcmcat128500050004': {'id': 'pcmcat128500050004',
#   'name': 'Name Brands',
#   'count': 4479,
#   'parent_id': 'cat00000'},
#  'pcmcat230000050010': {'id': 'pcmcat230000050010',
#   'name': 'Buy Back Program',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'pcmcat102500050032': {'id': 'pcmcat102500050032',
#   'name': 'Financing and Rewards',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'pcmcat159800050001': {'id': 'pcmcat159800050001',
#   'name': 'Geek Squad Protection',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'pcmcat226500050012': {'id': 'pcmcat226500050012',
#   'name': 'Appliance Install Delivery Repair',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'cat09000': {'id': 'cat09000',
#   'name': 'Best Buy Gift Cards',
#   'count': 1,
#   'parent_id': 'cat00000'},
#  'abcat0400000': {'id': 'abcat0400000',
#   'name': 'Cameras & Camcorders',
#   'count': 18460,
#   'parent_id': 'cat00000'},
#  'pcmcat254400050000': {'id': 'pcmcat254400050000',
#   'name': 'Deals Near Me',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'abcat0900000': {'id': 'abcat0900000',
#   'name': 'Appliances',
#   'count': 20851,
#   'parent_id': 'cat00000'},
#  'pcmcat142300050026': {'id': 'pcmcat142300050026',
#   'name': 'Outlet Center',
#   'count': 346,
#   'parent_id': 'cat00000'},
#  'abcat0010000': {'id': 'abcat0010000',
#   'name': 'Gift Center',
#   'count': 29,
#   'parent_id': 'cat00000'},
#  'pcmcat242800050021': {'id': 'pcmcat242800050021',
#   'name': 'Health, Fitness & Sports',
#   'count': 5716,
#   'parent_id': 'cat00000'},
#  'pcmcat200300050008': {'id': 'pcmcat200300050008',
#   'name': 'pc app Downloads',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'pcmcat253300050001': {'id': 'pcmcat253300050001',
#   'name': 'Appcessories™',
#   'count': 170,
#   'parent_id': 'cat00000'},
#  'abcat0500000': {'id': 'abcat0500000',
#   'name': 'Computers & Tablets',
#   'count': 63705,
#   'parent_id': 'cat00000'},
#  'pcmcat230900050001': {'id': 'pcmcat230900050001',
#   'name': 'Best Buy For Business',
#   'count': 5475,
#   'parent_id': 'cat00000'},
#  'pcmcat138100050018': {'id': 'pcmcat138100050018',
#   'name': 'Geek Squad',
#   'count': 141,
#   'parent_id': 'cat00000'},
#  'pcmcat87800050001': {'id': 'pcmcat87800050001',
#   'name': 'Customer Service',
#   'count': 0,
#   'parent_id': 'cat00000'},
#  'abcat0207000': {'id': 'abcat0207000',
#   'name': 'Musical Instruments',
#   'count': 3246,
#   'parent_id': 'cat00000'},
#  'pcmcat139900050002': {'id': 'pcmcat139900050002',
#   'name': 'Magnolia Home Theater',
#   'count': 1032,
#   'parent_id': 'cat00000'},
#  'pcmcat203600050025': {'id': 'pcmcat203600050025',
#   'name': 'Mobile Plans',
#   'count': 659,
#   'parent_id': 'abcat0800000'},
#  'pcmcat230800050018': {'id': 'pcmcat230800050018',
#   'name': 'Digital Movies',
#   'count': 36,
#   'parent_id': 'abcat0600000'},
#  'pcmcat212100050006': {'id': 'pcmcat212100050006',
#   'name': 'Corel',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat211900050000': {'id': 'pcmcat211900050000',
#   'name': 'Viper',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0902000': {'id': 'abcat0902000',
#   'name': 'Freezers & Ice Makers',
#   'count': 397,
#   'parent_id': 'abcat0900000'},
#  'abcat0903000': {'id': 'abcat0903000',
#   'name': 'Microwaves',
#   'count': 1163,
#   'parent_id': 'abcat0900000'},
#  'pcmcat196200050018': {'id': 'pcmcat196200050018',
#   'name': 'Club Beats',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0904000': {'id': 'abcat0904000',
#   'name': 'Ranges & Ovens',
#   'count': 1435,
#   'parent_id': 'abcat0900000'},
#  'pcmcat196700050004': {'id': 'pcmcat196700050004',
#   'name': 'Roxio',
#   'count': 19,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat211000050003': {'id': 'pcmcat211000050003',
#   'name': 'Home Energy Technology',
#   'count': 68,
#   'parent_id': 'pcmcat248700050021'},
#  'abcat0901000': {'id': 'abcat0901000',
#   'name': 'Refrigerators',
#   'count': 2645,
#   'parent_id': 'abcat0900000'},
#  'abcat0809000': {'id': 'abcat0809000',
#   'name': 'Office Furniture',
#   'count': 394,
#   'parent_id': 'pcmcat245100050028'},
#  'pcmcat214000050005': {'id': 'pcmcat214000050005',
#   'name': 'Compact System Cameras',
#   'count': 473,
#   'parent_id': 'abcat0400000'},
#  'abcat0905000': {'id': 'abcat0905000',
#   'name': 'Dishwashers',
#   'count': 791,
#   'parent_id': 'abcat0900000'},
#  'abcat0714000': {'id': 'abcat0714000',
#   'name': "Toys & Kids' Electronics",
#   'count': 32,
#   'parent_id': 'abcat0700000'},
#  'pcmcat252700050006': {'id': 'pcmcat252700050006',
#   'name': 'Toys & Games',
#   'count': 678,
#   'parent_id': 'pcmcat248700050021'},
#  'pcmcat221600050000': {'id': 'pcmcat221600050000',
#   'name': 'Bowers & Wilkins',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat220400050001': {'id': 'pcmcat220400050001',
#   'name': 'Rosetta Stone',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0801002': {'id': 'abcat0801002',
#   'name': 'No-Contract Phones',
#   'count': 3425,
#   'parent_id': 'abcat0800000'},
#  'abcat0802000': {'id': 'abcat0802000',
#   'name': 'Telephones & Communication',
#   'count': 1832,
#   'parent_id': 'pcmcat245100050028'},
#  'pcmcat213800050001': {'id': 'pcmcat213800050001',
#   'name': 'BlackBerry',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat217800050001': {'id': 'pcmcat217800050001',
#   'name': 'test',
#   'count': 0,
#   'parent_id': 'abcat0500000'},
#  'pcmcat214700050032': {'id': 'pcmcat214700050032',
#   'name': 'Wireless Internet',
#   'count': 0,
#   'parent_id': 'abcat0500000'},
#  'pcmcat214100050018': {'id': 'pcmcat214100050018',
#   'name': 'Kicker',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0808000': {'id': 'abcat0808000',
#   'name': 'Paper',
#   'count': 358,
#   'parent_id': 'pcmcat245100050028'},
#  'pcmcat214100050013': {'id': 'pcmcat214100050013',
#   'name': 'Corsair',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat195500050023': {'id': 'pcmcat195500050023',
#   'name': 'AT&T',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat195600050002': {'id': 'pcmcat195600050002',
#   'name': 'TomTom',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0807000': {'id': 'abcat0807000',
#   'name': 'Printer Ink & Toner',
#   'count': 919,
#   'parent_id': 'pcmcat245100050028'},
#  'abcat0906000': {'id': 'abcat0906000',
#   'name': 'Compactors & Disposals',
#   'count': 206,
#   'parent_id': 'abcat0900000'},
#  'abcat0907000': {'id': 'abcat0907000',
#   'name': 'Air Conditioners, Fans & Heaters',
#   'count': 792,
#   'parent_id': 'abcat0900000'},
#  'cat02015': {'id': 'cat02015',
#   'name': 'Movies & TV Shows',
#   'count': 22905,
#   'parent_id': 'abcat0600000'},
#  'pcmcat208100050003': {'id': 'pcmcat208100050003',
#   'name': 'Verizon Wireless',
#   'count': 164,
#   'parent_id': 'abcat0800000'},
#  'pcmcat208100050002': {'id': 'pcmcat208100050002',
#   'name': 'AT&T',
#   'count': 0,
#   'parent_id': 'abcat0800000'},
#  'pcmcat208100050001': {'id': 'pcmcat208100050001',
#   'name': 'Sprint',
#   'count': 0,
#   'parent_id': 'abcat0800000'},
#  'pcmcat205700050020': {'id': 'pcmcat205700050020',
#   'name': 'Folk Instruments',
#   'count': 34,
#   'parent_id': 'abcat0207000'},
#  'pcmcat253700050020': {'id': 'pcmcat253700050020',
#   'name': 'Weather Stations & Clocks',
#   'count': 230,
#   'parent_id': 'pcmcat248700050021'},
#  'pcmcat205600050012': {'id': 'pcmcat205600050012',
#   'name': 'TurboTax',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat208100050004': {'id': 'pcmcat208100050004',
#   'name': 'T-Mobile',
#   'count': 0,
#   'parent_id': 'abcat0800000'},
#  'pcmcat243800050004': {'id': 'pcmcat243800050004',
#   'name': 'Health & Wellness Technology',
#   'count': 394,
#   'parent_id': 'pcmcat242800050021'},
#  'pcmcat205600050010': {'id': 'pcmcat205600050010',
#   'name': 'Quicken',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat205300050001': {'id': 'pcmcat205300050001',
#   'name': 'Kaspersky Lab',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat203400050001': {'id': 'pcmcat203400050001',
#   'name': 'Help',
#   'count': 0,
#   'parent_id': 'pcmcat87800050001'},
#  'abcat0916006': {'id': 'abcat0916006',
#   'name': 'Replacement Water Filters',
#   'count': 224,
#   'parent_id': 'abcat0900000'},
#  'pcmcat204200050016': {'id': 'pcmcat204200050016',
#   'name': 'HTC',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0916000': {'id': 'abcat0916000',
#   'name': 'Appliance Accessories',
#   'count': 1,
#   'parent_id': 'abcat0900000'},
#  'pcmcat205600050011': {'id': 'pcmcat205600050011',
#   'name': 'QuickBooks',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat210800050014': {'id': 'pcmcat210800050014',
#   'name': 'iFrogz',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat208400050010': {'id': 'pcmcat208400050010',
#   'name': 'Bosch',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0912001': {'id': 'abcat0912001',
#   'name': 'Garment Care',
#   'count': 310,
#   'parent_id': 'abcat0900000'},
#  'pcmcat203500050000': {'id': 'pcmcat203500050000',
#   'name': 'Pre-Owned & Refurbished',
#   'count': 3211,
#   'parent_id': 'abcat0700000'},
#  'pcmcat210600050000': {'id': 'pcmcat210600050000',
#   'name': 'Kingston',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat210400050001': {'id': 'pcmcat210400050001',
#   'name': 'Rocketfish',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat200900050008': {'id': 'pcmcat200900050008',
#   'name': 'Portable TV & Video',
#   'count': 452,
#   'parent_id': 'abcat0100000'},
#  'abcat0908000': {'id': 'abcat0908000',
#   'name': 'Air Purifiers & Dehumidifiers',
#   'count': 561,
#   'parent_id': 'abcat0900000'},
#  'abcat0909000': {'id': 'abcat0909000',
#   'name': 'Water Filtration',
#   'count': 0,
#   'parent_id': 'abcat0900000'},
#  'pcmcat208600050001': {'id': 'pcmcat208600050001',
#   'name': 'Samsung Mobile',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0910000': {'id': 'abcat0910000',
#   'name': 'Washers & Dryers',
#   'count': 2358,
#   'parent_id': 'abcat0900000'},
#  'abcat0911000': {'id': 'abcat0911000',
#   'name': 'Vacuum Cleaners',
#   'count': 1854,
#   'parent_id': 'abcat0900000'},
#  'abcat0713000': {'id': 'abcat0713000',
#   'name': 'Online Games',
#   'count': 0,
#   'parent_id': 'abcat0700000'},
#  'pcmcat209400050001': {'id': 'pcmcat209400050001',
#   'name': 'All Mobile Phones with Plans',
#   'count': 4907,
#   'parent_id': 'abcat0800000'},
#  'pcmcat209000050006': {'id': 'pcmcat209000050006',
#   'name': 'Tablets & iPad',
#   'count': 13131,
#   'parent_id': 'abcat0500000'},
#  'cat02001': {'id': 'cat02001',
#   'name': 'Music',
#   'count': 12475,
#   'parent_id': 'abcat0600000'},
#  'abcat0912000': {'id': 'abcat0912000',
#   'name': 'Small Appliances',
#   'count': 1005,
#   'parent_id': 'abcat0900000'},
#  'pcmcat209800050001': {'id': 'pcmcat209800050001',
#   'name': 'As Seen On TV',
#   'count': 102,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0712000': {'id': 'abcat0712000',
#   'name': 'PC Gaming',
#   'count': 50,
#   'parent_id': 'abcat0700000'},
#  'pcmcat226400050024': {'id': 'pcmcat226400050024',
#   'name': 'Camera & Camcorder Services',
#   'count': 35,
#   'parent_id': 'pcmcat138100050018'},
#  'pcmcat222000050000': {'id': 'pcmcat222000050000',
#   'name': 'Music Lessons',
#   'count': 1,
#   'parent_id': 'abcat0207000'},
#  'pcmcat246900050017': {'id': 'pcmcat246900050017',
#   'name': 'Portable Fitness fake',
#   'count': 0,
#   'parent_id': 'pcmcat242800050021'},
#  'pcmcat246300050007': {'id': 'pcmcat246300050007',
#   'name': 'OnStar',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat246100050003': {'id': 'pcmcat246100050003',
#   'name': 'Blue Microphones',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0508000': {'id': 'abcat0508000',
#   'name': 'Software',
#   'count': 4816,
#   'parent_id': 'abcat0500000'},
#  'abcat0508003': {'id': 'abcat0508003',
#   'name': 'Office & Business Software',
#   'count': 954,
#   'parent_id': 'pcmcat245100050028'},
#  'pcmcat243500050029': {'id': 'pcmcat243500050029',
#   'name': 'Gen-16',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat243400050029': {'id': 'pcmcat243400050029',
#   'name': 'PS Vita',
#   'count': 0,
#   'parent_id': 'abcat0700000'},
#  'pcmcat243400050026': {'id': 'pcmcat243400050026',
#   'name': 'Zildjian',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat251300050011': {'id': 'pcmcat251300050011',
#   'name': 'Tools',
#   'count': 236,
#   'parent_id': 'pcmcat248700050021'},
#  'abcat0509000': {'id': 'abcat0509000',
#   'name': 'Monitors',
#   'count': 1966,
#   'parent_id': 'abcat0500000'},
#  'abcat0510000': {'id': 'abcat0510000',
#   'name': 'Projectors',
#   'count': 0,
#   'parent_id': 'abcat0500000'},
#  'abcat0511000': {'id': 'abcat0511000',
#   'name': 'Printers, Scanners & Fax',
#   'count': 0,
#   'parent_id': 'pcmcat245100050028'},
#  'abcat0511001': {'id': 'abcat0511001',
#   'name': 'Printers',
#   'count': 2731,
#   'parent_id': 'pcmcat245100050028'},
#  'pcmcat241100050019': {'id': 'pcmcat241100050019',
#   'name': 'GoPro Store',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0511006': {'id': 'abcat0511006',
#   'name': 'Photo Printers',
#   'count': 247,
#   'parent_id': 'abcat0400000'},
#  'pcmcat246900050018': {'id': 'pcmcat246900050018',
#   'name': 'Personal Care fake',
#   'count': 0,
#   'parent_id': 'pcmcat242800050021'},
#  'abcat0511007': {'id': 'abcat0511007',
#   'name': 'Scanners',
#   'count': 358,
#   'parent_id': 'pcmcat245100050028'},
#  'abcat0504010': {'id': 'abcat0504010',
#   'name': 'USB Flash Drives',
#   'count': 1084,
#   'parent_id': 'abcat0500000'},
#  'abcat0504000': {'id': 'abcat0504000',
#   'name': 'Hard Drives & Storage',
#   'count': 0,
#   'parent_id': 'abcat0500000'},
#  'pcmcat252500050045': {'id': 'pcmcat252500050045',
#   'name': 'Jawbone Bluetooth',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat252500050041': {'id': 'pcmcat252500050041',
#   'name': 'Kobo',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat251300050009': {'id': 'pcmcat251300050009',
#   'name': 'iPhone Appcessories™ Products',
#   'count': 48,
#   'parent_id': 'pcmcat253300050001'},
#  'abcat0501000': {'id': 'abcat0501000',
#   'name': 'Desktop & All-in-One Computers',
#   'count': 4201,
#   'parent_id': 'abcat0500000'},
#  'pcmcat250600050010': {'id': 'pcmcat250600050010',
#   'name': 'Online Photo & Video Services',
#   'count': 0,
#   'parent_id': 'abcat0400000'},
#  'abcat0502000': {'id': 'abcat0502000',
#   'name': 'Laptop & Netbook Computers',
#   'count': 16989,
#   'parent_id': 'abcat0500000'},
#  'pcmcat254300050005': {'id': 'pcmcat254300050005',
#   'name': 'Outdoor Recreation',
#   'count': 6,
#   'parent_id': 'pcmcat248700050021'},
#  'abcat0503000': {'id': 'abcat0503000',
#   'name': 'Networking & Wireless',
#   'count': 5599,
#   'parent_id': 'abcat0500000'},
#  'pcmcat154200050035': {'id': 'pcmcat154200050035',
#   'name': 'Small Business & Home Office Essentials',
#   'count': 5475,
#   'parent_id': 'pcmcat230900050001'},
#  'pcmcat249300050012': {'id': 'pcmcat249300050012',
#   'name': 'Pacific Sales',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat249000050000': {'id': 'pcmcat249000050000',
#   'name': 'Personal Care Appliances',
#   'count': 0,
#   'parent_id': 'abcat0900000'},
#  'pcmcat248300050015': {'id': 'pcmcat248300050015',
#   'name': 'Deal of the Day FAQs',
#   'count': 0,
#   'parent_id': 'pcmcat248000050016'},
#  'abcat0507000': {'id': 'abcat0507000',
#   'name': 'Computer Cards & Components',
#   'count': 4971,
#   'parent_id': 'abcat0500000'},
#  'pcmcat253700050018': {'id': 'pcmcat253700050018',
#   'name': 'Luggage, Bags & Travel',
#   'count': 132,
#   'parent_id': 'pcmcat248700050021'},
#  'pcmcat248100050017': {'id': 'pcmcat248100050017',
#   'name': 'VTech Toys',
#   'count': 1,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0504001': {'id': 'abcat0504001',
#   'name': 'Hard Drives',
#   'count': 3426,
#   'parent_id': 'abcat0500000'},
#  'abcat0711000': {'id': 'abcat0711000',
#   'name': 'Game Guides',
#   'count': 441,
#   'parent_id': 'abcat0700000'},
#  'abcat0511011': {'id': 'abcat0511011',
#   'name': 'Fax Machines/Copiers',
#   'count': 84,
#   'parent_id': 'pcmcat245100050028'},
#  'abcat0513000': {'id': 'abcat0513000',
#   'name': 'Mice & Keyboards',
#   'count': 2384,
#   'parent_id': 'abcat0500000'},
#  'pcmcat230000050013': {'id': 'pcmcat230000050013',
#   'name': 'Buy Back Program Terms and Conditions',
#   'count': 0,
#   'parent_id': 'pcmcat230000050010'},
#  'pcmcat153600050007': {'id': 'pcmcat153600050007',
#   'name': 'Game Downloads',
#   'count': 424,
#   'parent_id': 'abcat0700000'},
#  'pcmcat270900050006': {'id': 'pcmcat270900050006',
#   'name': 'Classic Video Game Systems',
#   'count': 332,
#   'parent_id': 'abcat0700000'},
#  'abcat0703000': {'id': 'abcat0703000',
#   'name': 'PlayStation 3',
#   'count': 2109,
#   'parent_id': 'abcat0700000'},
#  'pcmcat229000050002': {'id': 'pcmcat229000050002',
#   'name': 'MyPublisher',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat227000050000': {'id': 'pcmcat227000050000',
#   'name': 'West Coast Customs',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat195400050017': {'id': 'pcmcat195400050017',
#   'name': 'VTech',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat273800050017': {'id': 'pcmcat273800050017',
#   'name': 'Sports & Outdoor Recreation',
#   'count': 1329,
#   'parent_id': 'pcmcat242800050021'},
#  'abcat0705000': {'id': 'abcat0705000',
#   'name': 'PSP',
#   'count': 574,
#   'parent_id': 'abcat0700000'},
#  'pcmcat224100050004': {'id': 'pcmcat224100050004',
#   'name': 'Refurbished',
#   'count': 48,
#   'parent_id': 'pcmcat142300050026'},
#  'abcat0706000': {'id': 'abcat0706000',
#   'name': 'Wii',
#   'count': 638,
#   'parent_id': 'abcat0700000'},
#  'pcmcat223500050003': {'id': 'pcmcat223500050003',
#   'name': 'Otterbox',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0707000': {'id': 'abcat0707000',
#   'name': 'Nintendo DS',
#   'count': 646,
#   'parent_id': 'abcat0700000'},
#  'pcmcat223200050005': {'id': 'pcmcat223200050005',
#   'name': 'Philips',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat222200050000': {'id': 'pcmcat222200050000',
#   'name': 'Shutterfly',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat230600050000': {'id': 'pcmcat230600050000',
#   'name': 'Lenovo',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0805000': {'id': 'abcat0805000',
#   'name': 'Office Electronics',
#   'count': 637,
#   'parent_id': 'pcmcat245100050028'},
#  'pcmcat135300050050': {'id': 'pcmcat135300050050',
#   'name': 'Microsoft',
#   'count': 3601,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0603000': {'id': 'abcat0603000',
#   'name': 'Books',
#   'count': 0,
#   'parent_id': 'abcat0600000'},
#  'pcmcat239700050008': {'id': 'pcmcat239700050008',
#   'name': 'Spot It Out',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat239100050009': {'id': 'pcmcat239100050009',
#   'name': 'Eye-fi',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat238900050009': {'id': 'pcmcat238900050009',
#   'name': 'GoPro',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat238300050021': {'id': 'pcmcat238300050021',
#   'name': 'Gift Cards',
#   'count': 1,
#   'parent_id': 'cat09000'},
#  'abcat0515000': {'id': 'abcat0515000',
#   'name': 'Accessories',
#   'count': 3602,
#   'parent_id': 'abcat0500000'},
#  'pcmcat244200050008': {'id': 'pcmcat244200050008',
#   'name': 'Cartoon & Popular Characters',
#   'count': 588,
#   'parent_id': 'pcmcat248700050021'},
#  'abcat0715000': {'id': 'abcat0715000',
#   'name': 'Accessories',
#   'count': 1429,
#   'parent_id': 'abcat0700000'},
#  'pcmcat234900050002': {'id': 'pcmcat234900050002',
#   'name': 'Gibson Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat234000050008': {'id': 'pcmcat234000050008',
#   'name': 'iMemories',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat233100050008': {'id': 'pcmcat233100050008',
#   'name': 'Licensed Products',
#   'count': 0,
#   'parent_id': 'pcmcat248700050021'},
#  'abcat0811000': {'id': 'abcat0811000',
#   'name': 'Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat245100050028'},
#  'pcmcat232900050010': {'id': 'pcmcat232900050010',
#   'name': 'Trade-in Games',
#   'count': 0,
#   'parent_id': 'abcat0700000'},
#  'pcmcat232900050000': {'id': 'pcmcat232900050000',
#   'name': 'Nintendo 3DS',
#   'count': 2,
#   'parent_id': 'abcat0700000'},
#  'pcmcat231900050003': {'id': 'pcmcat231900050003',
#   'name': 'eGift Cards',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'abcat0602000': {'id': 'abcat0602000',
#   'name': 'Digital Music Downloads',
#   'count': 0,
#   'parent_id': 'abcat0600000'},
#  'abcat0604000': {'id': 'abcat0604000',
#   'name': 'Podcasts & Streams',
#   'count': 0,
#   'parent_id': 'abcat0600000'},
#  'pcmcat195200050008': {'id': 'pcmcat195200050008',
#   'name': 'Sony Reader',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat190800050009': {'id': 'pcmcat190800050009',
#   'name': 'Jabra',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat194500050008': {'id': 'pcmcat194500050008',
#   'name': 'SiriusXM',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat152100050010': {'id': 'pcmcat152100050010',
#   'name': 'Drums & Percussion',
#   'count': 163,
#   'parent_id': 'abcat0207000'},
#  'pcmcat128500050005': {'id': 'pcmcat128500050005',
#   'name': 'Apple',
#   'count': 43,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat151900050007': {'id': 'pcmcat151900050007',
#   'name': 'Panasonic',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat151700050000': {'id': 'pcmcat151700050000',
#   'name': 'Showtime',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat132700050016': {'id': 'pcmcat132700050016',
#   'name': 'Digital Imaging Tools',
#   'count': 0,
#   'parent_id': 'abcat0400000'},
#  'pcmcat151600050037': {'id': 'pcmcat151600050037',
#   'name': 'Keyboards',
#   'count': 416,
#   'parent_id': 'abcat0207000'},
#  'pcmcat133000050031': {'id': 'pcmcat133000050031',
#   'name': 'LG',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat127000050003': {'id': 'pcmcat127000050003',
#   'name': 'Garmin GPS',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat151600050019': {'id': 'pcmcat151600050019',
#   'name': 'Amps & Effects',
#   'count': 285,
#   'parent_id': 'abcat0207000'},
#  'pcmcat151600050002': {'id': 'pcmcat151600050002',
#   'name': 'Guitars',
#   'count': 655,
#   'parent_id': 'abcat0207000'},
#  'pcmcat151300050000': {'id': 'pcmcat151300050000',
#   'name': 'Magellan GPS',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat134600050009': {'id': 'pcmcat134600050009',
#   'name': 'Pioneer Electronics',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat134600050010': {'id': 'pcmcat134600050010',
#   'name': 'Sanus',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat151000050010': {'id': 'pcmcat151000050010',
#   'name': 'Linksys',
#   'count': 48,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat150300050000': {'id': 'pcmcat150300050000',
#   'name': 'Polk Audio',
#   'count': 17,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat149900050041': {'id': 'pcmcat149900050041',
#   'name': 'George',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat133100050006': {'id': 'pcmcat133100050006',
#   'name': 'Velocity Micro',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat149900050022': {'id': 'pcmcat149900050022',
#   'name': 'McAfee',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat123000050004': {'id': 'pcmcat123000050004',
#   'name': 'XFX',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat50000050006': {'id': 'pcmcat50000050006',
#   'name': 'Dynex',
#   'count': 64,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat154300050024': {'id': 'pcmcat154300050024',
#   'name': 'Hoover',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat74600050004': {'id': 'pcmcat74600050004',
#   'name': 'Dirt Devil',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat153600050014': {'id': 'pcmcat153600050014',
#   'name': 'EA Sports',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat153400050000': {'id': 'pcmcat153400050000',
#   'name': 'Discovery',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcat17093': {'id': 'pcat17093',
#   'name': 'Video Game Trade-In',
#   'count': 0,
#   'parent_id': 'abcat0700000'},
#  'pcmcat154200050001': {'id': 'pcmcat154200050001',
#   'name': 'Frigidaire',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat102800050018': {'id': 'pcmcat102800050018',
#   'name': 'Zune',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat152100050020': {'id': 'pcmcat152100050020',
#   'name': 'Recording Equipment',
#   'count': 818,
#   'parent_id': 'abcat0200000'},
#  'pcmcat103600050007': {'id': 'pcmcat103600050007',
#   'name': 'Liz Claiborne Cases',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat152600050013': {'id': 'pcmcat152600050013',
#   'name': 'Brother Printers & Fax',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat152600050004': {'id': 'pcmcat152600050004',
#   'name': 'Optoma Projectors',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat152200050014': {'id': 'pcmcat152200050014',
#   'name': 'Sheet Music & DVDs',
#   'count': 184,
#   'parent_id': 'abcat0207000'},
#  'pcmcat111900050004': {'id': 'pcmcat111900050004',
#   'name': 'Pink and Red Gifts',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat152100050035': {'id': 'pcmcat152100050035',
#   'name': 'Live Sound & Microphones',
#   'count': 662,
#   'parent_id': 'abcat0207000'},
#  'pcmcat84000050003': {'id': 'pcmcat84000050003',
#   'name': 'Graduations',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat152100050027': {'id': 'pcmcat152100050027',
#   'name': 'DJ & Lighting Equipment',
#   'count': 729,
#   'parent_id': 'abcat0207000'},
#  'pcmcat110200050031': {'id': 'pcmcat110200050031',
#   'name': 'Windows Vista',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat154500050003': {'id': 'pcmcat154500050003',
#   'name': 'ATI',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat135200050014': {'id': 'pcmcat135200050014',
#   'name': 'Casio',
#   'count': 19,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat147200050008': {'id': 'pcmcat147200050008',
#   'name': 'AMD Processors',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat140900050016': {'id': 'pcmcat140900050016',
#   'name': 'Canon',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat137700050018': {'id': 'pcmcat137700050018',
#   'name': 'Chief',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat140800050115': {'id': 'pcmcat140800050115',
#   'name': 'Samsung',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat140500050010': {'id': 'pcmcat140500050010',
#   'name': 'Dell Computers',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat140000050042': {'id': 'pcmcat140000050042',
#   'name': 'Enjoying Favorite Movies',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat140000050041': {'id': 'pcmcat140000050041',
#   'name': 'Watching HDTV',
#   'count': 8,
#   'parent_id': 'abcat0010000'},
#  'pcmcat138100050024': {'id': 'pcmcat138100050024',
#   'name': 'TV & Home Theater Services',
#   'count': 332,
#   'parent_id': 'abcat0200000'},
#  'pcmcat142400050015': {'id': 'pcmcat142400050015',
#   'name': 'Bissell',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat138100050025': {'id': 'pcmcat138100050025',
#   'name': 'Car Installation',
#   'count': 0,
#   'parent_id': 'pcmcat138100050018'},
#  'pcmcat140000050039': {'id': 'pcmcat140000050039',
#   'name': 'Simple GPS Navigation',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat140000050037': {'id': 'pcmcat140000050037',
#   'name': 'Computing Made Easy',
#   'count': 17,
#   'parent_id': 'abcat0010000'},
#  'pcmcat140000050036': {'id': 'pcmcat140000050036',
#   'name': 'Listening to Digital Music',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat140000050035': {'id': 'pcmcat140000050035',
#   'name': 'Capturing Photos & Videos',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat140000050019': {'id': 'pcmcat140000050019',
#   'name': 'Western Digital',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat139900050006': {'id': 'pcmcat139900050006',
#   'name': 'Epson',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat138900050012': {'id': 'pcmcat138900050012',
#   'name': 'Slingbox',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat140000050040': {'id': 'pcmcat140000050040',
#   'name': 'Playing Video Games',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat149000050005': {'id': 'pcmcat149000050005',
#   'name': 'Blu-ray',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat137400050055': {'id': 'pcmcat137400050055',
#   'name': 'Bush Furniture',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat143000050025': {'id': 'pcmcat143000050025',
#   'name': 'KitchenAid',
#   'count': 4,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat145500050036': {'id': 'pcmcat145500050036',
#   'name': 'HP',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat135300050002': {'id': 'pcmcat135300050002',
#   'name': 'Kodak',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat135300050020': {'id': 'pcmcat135300050020',
#   'name': 'Lexmark Printers',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat135300050024': {'id': 'pcmcat135300050024',
#   'name': 'PNY',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat143700050011': {'id': 'pcmcat143700050011',
#   'name': 'Electrolux Appliances',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat143200050028': {'id': 'pcmcat143200050028',
#   'name': 'TV & Video Accessories',
#   'count': 190,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat143200050027': {'id': 'pcmcat143200050027',
#   'name': 'Audio Accessories',
#   'count': 127,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat143000050020': {'id': 'pcmcat143000050020',
#   'name': 'Studio RTA',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat136200050016': {'id': 'pcmcat136200050016',
#   'name': 'D-Link',
#   'count': 67,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat143200050025': {'id': 'pcmcat143200050025',
#   'name': 'Furniture and Mounts',
#   'count': 186,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat143200050024': {'id': 'pcmcat143200050024',
#   'name': 'Home Theater Systems',
#   'count': 20,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat143200050023': {'id': 'pcmcat143200050023',
#   'name': 'Receivers',
#   'count': 17,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat143200050022': {'id': 'pcmcat143200050022',
#   'name': 'Speakers',
#   'count': 43,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat143200050021': {'id': 'pcmcat143200050021',
#   'name': 'Blu-ray and DVD Players',
#   'count': 6,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat143200050016': {'id': 'pcmcat143200050016',
#   'name': 'Televisions',
#   'count': 443,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat136800050058': {'id': 'pcmcat136800050058',
#   'name': 'Toshiba',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat143200050026': {'id': 'pcmcat143200050026',
#   'name': 'Installation',
#   'count': 0,
#   'parent_id': 'pcmcat139900050002'},
#  'pcmcat155100050037': {'id': 'pcmcat155100050037',
#   'name': 'Gateway Computers',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat155300050007': {'id': 'pcmcat155300050007',
#   'name': 'Nikon Cameras',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat155600050003': {'id': 'pcmcat155600050003',
#   'name': 'Olympus',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat184400050020': {'id': 'pcmcat184400050020',
#   'name': 'Mobile Broadband',
#   'count': 1397,
#   'parent_id': 'abcat0800000'},
#  'pcmcat184000050010': {'id': 'pcmcat184000050010',
#   'name': 'History Channel',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat184000050009': {'id': 'pcmcat184000050009',
#   'name': 'A&E',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat184000050001': {'id': 'pcmcat184000050001',
#   'name': 'Griffin',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat183800050003': {'id': 'pcmcat183800050003',
#   'name': 'DW',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat183700050003': {'id': 'pcmcat183700050003',
#   'name': 'HBO',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat183200050011': {'id': 'pcmcat183200050011',
#   'name': 'Memorex',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat185200050009': {'id': 'pcmcat185200050009',
#   'name': 'iPod & MP3 Player Services',
#   'count': 4,
#   'parent_id': 'pcmcat138100050018'},
#  'pcmcat181800050004': {'id': 'pcmcat181800050004',
#   'name': 'Kenwood Car Audio',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat180700050000': {'id': 'pcmcat180700050000',
#   'name': 'Funimation',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat180300050007': {'id': 'pcmcat180300050007',
#   'name': 'Pentax Cameras & Optics',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat180100050007': {'id': 'pcmcat180100050007',
#   'name': 'Garage',
#   'count': 31,
#   'parent_id': 'abcat0900000'},
#  'pcmcat179100050006': {'id': 'pcmcat179100050006',
#   'name': 'Outdoor Living',
#   'count': 196,
#   'parent_id': 'pcmcat248700050021'},
#  'pcmcat178400050028': {'id': 'pcmcat178400050028',
#   'name': 'NVIDIA',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat177200050009': {'id': 'pcmcat177200050009',
#   'name': 'Electric Bikes & Scooters',
#   'count': 150,
#   'parent_id': 'abcat0900000'},
#  'pcmcat175700050012': {'id': 'pcmcat175700050012',
#   'name': 'Nuance',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat181500050017': {'id': 'pcmcat181500050017',
#   'name': 'Napster',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat175500050004': {'id': 'pcmcat175500050004',
#   'name': 'Squier Guitars',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat186000050007': {'id': 'pcmcat186000050007',
#   'name': 'Tom Clancy',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat186200050012': {'id': 'pcmcat186200050012',
#   'name': 'Eureka',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat223300050025': {'id': 'pcmcat223300050025',
#   'name': 'E-Readers',
#   'count': 1536,
#   'parent_id': 'abcat0500000'},
#  'pcmcat193100050003': {'id': 'pcmcat193100050003',
#   'name': 'Electronic Games & Learning',
#   'count': 0,
#   'parent_id': 'abcat0700000'},
#  'pcmcat192700050008': {'id': 'pcmcat192700050008',
#   'name': 'Incase',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat192300050018': {'id': 'pcmcat192300050018',
#   'name': 'Belkin',
#   'count': 28,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat192000050002': {'id': 'pcmcat192000050002',
#   'name': 'Alpine Car Audio',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat191600050011': {'id': 'pcmcat191600050011',
#   'name': 'Yamaha',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat252900050012': {'id': 'pcmcat252900050012',
#   'name': 'Outlet Center Test',
#   'count': 0,
#   'parent_id': 'pcmcat142300050026'},
#  'pcmcat186200050003': {'id': 'pcmcat186200050003',
#   'name': 'Electrolux Vacuums',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat190800050003': {'id': 'pcmcat190800050003',
#   'name': 'Flip Video',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat190000050006': {'id': 'pcmcat190000050006',
#   'name': 'ASUS',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat189200050005': {'id': 'pcmcat189200050005',
#   'name': 'AKG Headphones',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat188800050003': {'id': 'pcmcat188800050003',
#   'name': 'Skullcandy',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat188200050000': {'id': 'pcmcat188200050000',
#   'name': 'Audio & MP3 Services',
#   'count': 0,
#   'parent_id': 'abcat0200000'},
#  'pcmcat187300050021': {'id': 'pcmcat187300050021',
#   'name': 'Razer',
#   'count': 141,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat186700050011': {'id': 'pcmcat186700050011',
#   'name': '2K Sports',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat186500050003': {'id': 'pcmcat186500050003',
#   'name': 'Trade-In',
#   'count': 0,
#   'parent_id': 'abcat0700000'},
#  'pcmcat190000050016': {'id': 'pcmcat190000050016',
#   'name': 'Averatec',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat175400050004': {'id': 'pcmcat175400050004',
#   'name': 'Rockford Fosgate',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat175100050000': {'id': 'pcmcat175100050000',
#   'name': 'Sharp Electronics',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat171100050004': {'id': 'pcmcat171100050004',
#   'name': 'Video Game Pre-Orders',
#   'count': 0,
#   'parent_id': 'abcat0700000'},
#  'pcmcat159400050012': {'id': 'pcmcat159400050012',
#   'name': 'Strength & Weight Training',
#   'count': 512,
#   'parent_id': 'pcmcat242800050021'},
#  'pcmcat243800050005': {'id': 'pcmcat243800050005',
#   'name': 'Exercise Equipment',
#   'count': 487,
#   'parent_id': 'pcmcat242800050021'},
#  'pcmcat159400050006': {'id': 'pcmcat159400050006',
#   'name': 'Motorola',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat158900050008': {'id': 'pcmcat158900050008',
#   'name': 'Projectors & Screens',
#   'count': 1222,
#   'parent_id': 'abcat0100000'},
#  'pcmcat158600050000': {'id': 'pcmcat158600050000',
#   'name': 'NETGEAR',
#   'count': 306,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat158500050029': {'id': 'pcmcat158500050029',
#   'name': 'GE Appliances',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat157500050005': {'id': 'pcmcat157500050005',
#   'name': 'Guitar Hero',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat159400050013': {'id': 'pcmcat159400050013',
#   'name': 'Yoga, Pilates & Core Training',
#   'count': 115,
#   'parent_id': 'pcmcat242800050021'},
#  'pcmcat157300050001': {'id': 'pcmcat157300050001',
#   'name': 'Whirlpool',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat156900050006': {'id': 'pcmcat156900050006',
#   'name': 'A&E and History',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat156600050000': {'id': 'pcmcat156600050000',
#   'name': 'Denon',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat156500050009': {'id': 'pcmcat156500050009',
#   'name': 'HD Radio',
#   'count': 0,
#   'parent_id': 'abcat0200000'},
#  'pcmcat156400050037': {'id': 'pcmcat156400050037',
#   'name': 'Unlocked Mobile Phones',
#   'count': 975,
#   'parent_id': 'abcat0800000'},
#  'cat15063': {'id': 'cat15063',
#   'name': 'Sony',
#   'count': 18,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat156300050002': {'id': 'pcmcat156300050002',
#   'name': 'Criterion Collection',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat155800050048': {'id': 'pcmcat155800050048',
#   'name': 'Monster',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat157100050023': {'id': 'pcmcat157100050023',
#   'name': 'Maytag Appliances',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat159800050007': {'id': 'pcmcat159800050007',
#   'name': 'Insignia',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat161100050004': {'id': 'pcmcat161100050004',
#   'name': 'Intel',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat161100050046': {'id': 'pcmcat161100050046',
#   'name': 'Adobe',
#   'count': 1,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat169000050018': {'id': 'pcmcat169000050018',
#   'name': 'Nokia Phones',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat168900050013': {'id': 'pcmcat168900050013',
#   'name': 'Bose',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat166800050087': {'id': 'pcmcat166800050087',
#   'name': 'Webroot',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat166700050022': {'id': 'pcmcat166700050022',
#   'name': 'Navigon',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat166600050107': {'id': 'pcmcat166600050107',
#   'name': 'Seagate',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat166100050016': {'id': 'pcmcat166100050016',
#   'name': 'Last Chance Products',
#   'count': 0,
#   'parent_id': 'pcmcat142300050026'},
#  'pcmcat165900050004': {'id': 'pcmcat165900050004',
#   'name': 'Klipsch',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat165700050000': {'id': 'pcmcat165700050000',
#   'name': 'TiVo',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat165400050004': {'id': 'pcmcat165400050004',
#   'name': 'Gaming Setup & Services',
#   'count': 102,
#   'parent_id': 'pcmcat138100050018'},
#  'pcmcat164200050014': {'id': 'pcmcat164200050014',
#   'name': 'JVC',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat163800050029': {'id': 'pcmcat163800050029',
#   'name': 'LifeLock',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat163600050056': {'id': 'pcmcat163600050056',
#   'name': 'SanDisk',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat163500050008': {'id': 'pcmcat163500050008',
#   'name': 'Digital Radio',
#   'count': 0,
#   'parent_id': 'abcat0300000'},
#  'pcmcat163200050005': {'id': 'pcmcat163200050005',
#   'name': 'Books & Digital Audiobooks',
#   'count': 0,
#   'parent_id': 'abcat0600000'},
#  'pcmcat163100050004': {'id': 'pcmcat163100050004',
#   'name': 'Fender Guitars & Amps',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat162500050026': {'id': 'pcmcat162500050026',
#   'name': 'Dyson',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat161500050000': {'id': 'pcmcat161500050000',
#   'name': 'Refurbished Product',
#   'count': 298,
#   'parent_id': 'pcmcat142300050026'},
#  'pcmcat195200050007': {'id': 'pcmcat195200050007',
#   'name': 'iRex',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat253000050001': {'id': 'pcmcat253000050001',
#   'name': 'iPod Appcessories™ Products',
#   'count': 122,
#   'parent_id': 'pcmcat253300050001'},
#  'pcmcat208900050008': {'id': 'pcmcat208900050008',
#   'name': 'Trend Micro',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0409000': {'id': 'abcat0409000',
#   'name': 'Binoculars & Telescopes',
#   'count': 466,
#   'parent_id': 'abcat0400000'},
#  'abcat0020004': {'id': 'abcat0020004',
#   'name': 'Unique Gifts',
#   'count': 3,
#   'parent_id': 'abcat0010000'},
#  'abcat0207005': {'id': 'abcat0207005',
#   'name': 'Karaoke',
#   'count': 117,
#   'parent_id': 'abcat0207000'},
#  'pcmcat27200050015': {'id': 'pcmcat27200050015',
#   'name': 'FUJIFILM Digital Cameras',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0402000': {'id': 'abcat0402000',
#   'name': 'Film Cameras',
#   'count': 0,
#   'parent_id': 'abcat0400000'},
#  'pcmcat261800050020': {'id': 'pcmcat261800050020',
#   'name': 'Zoom',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0202000': {'id': 'abcat0202000',
#   'name': 'Audio Systems & Components',
#   'count': 1,
#   'parent_id': 'abcat0200000'},
#  'pcmcat145100050000': {'id': 'pcmcat145100050000',
#   'name': 'Batteries & Power',
#   'count': 2409,
#   'parent_id': 'abcat0900000'},
#  'abcat0913000': {'id': 'abcat0913000',
#   'name': 'Home Safety & Energy Management',
#   'count': 751,
#   'parent_id': 'pcmcat248700050021'},
#  'pcmcat68700050002': {'id': 'pcmcat68700050002',
#   'name': 'Init',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0410000': {'id': 'abcat0410000',
#   'name': 'Camera & Camcorder Accessories',
#   'count': 26,
#   'parent_id': 'abcat0400000'},
#  'pcmcat267600050026': {'id': 'pcmcat267600050026',
#   'name': 'Film Cameras & Accessories',
#   'count': 0,
#   'parent_id': 'abcat0400000'},
#  'pcmcat254000050002': {'id': 'pcmcat254000050002',
#   'name': 'Home Security & Safety',
#   'count': 582,
#   'parent_id': 'pcmcat248700050021'},
#  'pcmcat278000050000': {'id': 'pcmcat278000050000',
#   'name': 'Trailer Hitches, Car Racks & Accessories',
#   'count': 0,
#   'parent_id': 'abcat0300000'},
#  'pcmcat208400050005': {'id': 'pcmcat208400050005',
#   'name': 'Portable Fitness Electronics',
#   'count': 903,
#   'parent_id': 'pcmcat242800050021'},
#  'pcmcat253300050003': {'id': 'pcmcat253300050003',
#   'name': 'Audio Stands & Storage',
#   'count': 824,
#   'parent_id': 'abcat0200000'},
#  'abcat0201000': {'id': 'abcat0201000',
#   'name': 'iPod & MP3 Players',
#   'count': 875,
#   'parent_id': 'abcat0200000'},
#  'abcat0306000': {'id': 'abcat0306000',
#   'name': 'Remote Starters',
#   'count': 0,
#   'parent_id': 'abcat0300000'},
#  'abcat0401005': {'id': 'abcat0401005',
#   'name': 'Digital SLR Cameras',
#   'count': 3251,
#   'parent_id': 'abcat0400000'},
#  'pcmcat258400050039': {'id': 'pcmcat258400050039',
#   'name': 'Sony E-Readers',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0408000': {'id': 'abcat0408000',
#   'name': 'Digital Photo Frames',
#   'count': 404,
#   'parent_id': 'abcat0400000'},
#  'abcat0302038': {'id': 'abcat0302038',
#   'name': 'Marine Audio',
#   'count': 0,
#   'parent_id': 'abcat0200000'},
#  'pcmcat275000050000': {'id': 'pcmcat275000050000',
#   'name': 'Astro Gaming',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0407000': {'id': 'abcat0407000',
#   'name': 'Prepaid Cards',
#   'count': 0,
#   'parent_id': 'abcat0400000'},
#  'pcmcat257000050001': {'id': 'pcmcat257000050001',
#   'name': 'Open Box Sale Event',
#   'count': 0,
#   'parent_id': 'pcmcat254400050000'},
#  'pcmcat159400050007': {'id': 'pcmcat159400050007',
#   'name': 'Fitness',
#   'count': 3186,
#   'parent_id': 'abcat0900000'},
#  'abcat0302000': {'id': 'abcat0302000',
#   'name': 'Car Audio',
#   'count': 16534,
#   'parent_id': 'abcat0200000'},
#  'abcat0102000': {'id': 'abcat0102000',
#   'name': 'Blu-ray & DVD Players',
#   'count': 1766,
#   'parent_id': 'abcat0100000'},
#  'pcmcat275600050000': {'id': 'pcmcat275600050000',
#   'name': 'Office & School Supplies',
#   'count': 0,
#   'parent_id': 'pcmcat245100050028'},
#  'abcat0307000': {'id': 'abcat0307000',
#   'name': 'Car & GPS Accessories',
#   'count': 0,
#   'parent_id': 'abcat0300000'},
#  'pcmcat269700050002': {'id': 'pcmcat269700050002',
#   'name': 'iRobot',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0406000': {'id': 'abcat0406000',
#   'name': 'Photo Books & Gifts',
#   'count': 0,
#   'parent_id': 'abcat0400000'},
#  'abcat0204000': {'id': 'abcat0204000',
#   'name': 'Headphones',
#   'count': 6861,
#   'parent_id': 'abcat0200000'},
#  'abcat0106000': {'id': 'abcat0106000',
#   'name': 'TV Stands, Mounts & Storage',
#   'count': 2299,
#   'parent_id': 'abcat0100000'},
#  'pcmcat28300050012': {'id': 'pcmcat28300050012',
#   'name': 'Disney',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat4300050072': {'id': 'pcmcat4300050072',
#   'name': 'LeapFrog',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'pcmcat159400050014': {'id': 'pcmcat159400050014',
#   'name': 'Fitness Accessories',
#   'count': 1976,
#   'parent_id': 'pcmcat242800050021'},
#  'pcmcat256700050006': {'id': 'pcmcat256700050006',
#   'name': 'Amazon Kindle',
#   'count': 0,
#   'parent_id': 'pcmcat128500050004'},
#  'abcat0101000': {'id': 'abcat0101000',
#   'name': 'TVs',
#   'count': 12129,
#   'parent_id': 'abcat0100000'},
#  'abcat0020006': {'id': 'abcat0020006',
#   'name': 'Prepaid Cards',
#   'count': 0,
#   'parent_id': 'abcat0010000'},
#  'pcmcat241600050001': {'id': 'pcmcat241600050001',
#   'name': 'Home Audio',
#   'count': 8912,
#   'parent_id': 'abcat0200000'},
#  'pcmcat260500050000': {'id': 'pcmcat260500050000',
#   'name': 'Sennheiser',
# ...
#   'name': 'Whirlpool Ice Makers',
#   'count': 0,
#   'parent_id': 'pcmcat157300050001'},
#  'pcmcat157300050032': {'id': 'pcmcat157300050032',
#   'name': 'Whirlpool Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat157300050001'},
#  'pcmcat157300050004': {'id': 'pcmcat157300050004',
#   'name': 'Whirlpool Refrigerators',
#   'count': 0,
#   'parent_id': 'pcmcat157300050001'},
#  'pcmcat274600050016': {'id': 'pcmcat274600050016',
#   'name': 'Wii U Consoles',
#   'count': 0,
#   'parent_id': 'pcmcat273800050036'},
#  'pcmcat156900050013': {'id': 'pcmcat156900050013',
#   'name': 'Shockwave',
#   'count': 0,
#   'parent_id': 'pcmcat156900050006'},
#  'pcmcat156900050012': {'id': 'pcmcat156900050012',
#   'name': 'Battle 360',
#   'count': 0,
#   'parent_id': 'pcmcat156900050006'},
#  'pcmcat156600050001': {'id': 'pcmcat156600050001',
#   'name': 'Home Theater Systems',
#   'count': 0,
#   'parent_id': 'pcmcat156600050000'},
#  'pcmcat194000050011': {'id': 'pcmcat194000050011',
#   'name': 'Magnolia Home Theater',
#   'count': 0,
#   'parent_id': 'pcmcat156600050000'},
#  'pcmcat156600050003': {'id': 'pcmcat156600050003',
#   'name': 'DVD Players',
#   'count': 0,
#   'parent_id': 'pcmcat156600050000'},
#  'pcmcat156600050004': {'id': 'pcmcat156600050004',
#   'name': 'Receivers',
#   'count': 0,
#   'parent_id': 'pcmcat156600050000'},
#  'pcmcat156600050005': {'id': 'pcmcat156600050005',
#   'name': 'Shelf Systems',
#   'count': 0,
#   'parent_id': 'pcmcat156600050000'},
#  'pcmcat156700050003': {'id': 'pcmcat156700050003',
#   'name': 'HD Radio FAQs',
#   'count': 0,
#   'parent_id': 'pcmcat156500050009'},
#  'pcmcat156800050034': {'id': 'pcmcat156800050034',
#   'name': 'Deadliest Catch',
#   'count': 0,
#   'parent_id': 'pcmcat153400050000'},
#  'pcmcat156800050035': {'id': 'pcmcat156800050035',
#   'name': 'Dirty Jobs',
#   'count': 0,
#   'parent_id': 'pcmcat153400050000'},
#  'pcmcat188000050002': {'id': 'pcmcat188000050002',
#   'name': 'Music & Photo Backup',
#   'count': 0,
#   'parent_id': 'pcmcat185200050009'},
#  'pcmcat156800050041': {'id': 'pcmcat156800050041',
#   'name': 'MythBusters',
#   'count': 0,
#   'parent_id': 'pcmcat153400050000'},
#  'pcmcat156800050043': {'id': 'pcmcat156800050043',
#   'name': 'Shark Week',
#   'count': 0,
#   'parent_id': 'pcmcat153400050000'},
#  'pcmcat274600050017': {'id': 'pcmcat274600050017',
#   'name': 'Wii U Games',
#   'count': 0,
#   'parent_id': 'pcmcat273800050036'},
#  'pcmcat156900050007': {'id': 'pcmcat156900050007',
#   'name': 'Mindfreak',
#   'count': 0,
#   'parent_id': 'pcmcat156900050006'},
#  'pcmcat156900050009': {'id': 'pcmcat156900050009',
#   'name': 'Gene Simmons',
#   'count': 0,
#   'parent_id': 'pcmcat156900050006'},
#  'pcmcat156900050011': {'id': 'pcmcat156900050011',
#   'name': 'The Universe',
#   'count': 0,
#   'parent_id': 'pcmcat156900050006'},
#  'pcmcat275100050013': {'id': 'pcmcat275100050013',
#   'name': 'Bosch Freestanding Ranges',
#   'count': 0,
#   'parent_id': 'pcmcat208400050010'},
#  'pcmcat152100050013': {'id': 'pcmcat152100050013',
#   'name': 'Hardware',
#   'count': 19,
#   'parent_id': 'pcmcat152100050010'},
#  'pcmcat154400050046': {'id': 'pcmcat154400050046',
#   'name': 'Apps & Personalization',
#   'count': 0,
#   'parent_id': 'abcat0811002'},
#  'pcmcat154400050019': {'id': 'pcmcat154400050019',
#   'name': 'Computers',
#   'count': 0,
#   'parent_id': 'pcmcat154200050035'},
#  'pcmcat152100050039': {'id': 'pcmcat152100050039',
#   'name': 'PA Mixers',
#   'count': 62,
#   'parent_id': 'pcmcat152100050035'},
#  'pcmcat275600050013': {'id': 'pcmcat275600050013',
#   'name': 'Philips Headphones',
#   'count': 0,
#   'parent_id': 'pcmcat275600050012'},
#  'pcmcat152200050007': {'id': 'pcmcat152200050007',
#   'name': 'Power Amps',
#   'count': 64,
#   'parent_id': 'pcmcat152100050035'},
#  'pcmcat152200050008': {'id': 'pcmcat152200050008',
#   'name': 'Live Sound Speakers',
#   'count': 177,
#   'parent_id': 'pcmcat152100050035'},
#  'pcmcat152200050013': {'id': 'pcmcat152200050013',
#   'name': 'Live Sound Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat152100050035'},
#  'pcmcat152200050017': {'id': 'pcmcat152200050017',
#   'name': 'Auto Navigation',
#   'count': 0,
#   'parent_id': 'pcmcat151300050000'},
#  'pcmcat251600050003': {'id': 'pcmcat251600050003',
#   'name': 'Microphones & Accessories',
#   'count': 104,
#   'parent_id': 'pcmcat152100050035'},
#  'pcmcat152200050018': {'id': 'pcmcat152200050018',
#   'name': 'Outdoor Handheld',
#   'count': 0,
#   'parent_id': 'pcmcat151300050000'},
#  'pcmcat152600050005': {'id': 'pcmcat152600050005',
#   'name': 'Home Theater Projectors',
#   'count': 0,
#   'parent_id': 'pcmcat152600050004'},
#  'pcmcat152600050006': {'id': 'pcmcat152600050006',
#   'name': 'Multimedia Data Projectors',
#   'count': 0,
#   'parent_id': 'pcmcat152600050004'},
#  'pcmcat152600050007': {'id': 'pcmcat152600050007',
#   'name': 'Projector Screens',
#   'count': 0,
#   'parent_id': 'pcmcat152600050004'},
#  'pcmcat152600050008': {'id': 'pcmcat152600050008',
#   'name': 'Optoma Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat152600050004'},
#  'pcmcat275600050007': {'id': 'pcmcat275600050007',
#   'name': 'Arts & Crafts',
#   'count': 0,
#   'parent_id': 'pcmcat275600050000'},
#  'pcmcat152600050014': {'id': 'pcmcat152600050014',
#   'name': 'Printers',
#   'count': 0,
#   'parent_id': 'pcmcat152600050013'},
#  'pcmcat275600050008': {'id': 'pcmcat275600050008',
#   'name': 'Envelopes & Shipping Supplies',
#   'count': 0,
#   'parent_id': 'pcmcat275600050000'},
#  'pcmcat152600050015': {'id': 'pcmcat152600050015',
#   'name': 'Brother Fax Machines',
#   'count': 0,
#   'parent_id': 'pcmcat152600050013'},
#  'pcmcat275600050014': {'id': 'pcmcat275600050014',
#   'name': 'Philips Speakers & Clocks',
#   'count': 0,
#   'parent_id': 'pcmcat275600050012'},
#  'pcmcat152100050031': {'id': 'pcmcat152100050031',
#   'name': 'DJ Console Systems',
#   'count': 143,
#   'parent_id': 'pcmcat152100050027'},
#  'pcmcat152100050016': {'id': 'pcmcat152100050016',
#   'name': 'Electronic Drums',
#   'count': 0,
#   'parent_id': 'pcmcat152100050010'},
#  'pcmcat152100050017': {'id': 'pcmcat152100050017',
#   'name': 'World Percussion',
#   'count': 0,
#   'parent_id': 'pcmcat152100050010'},
#  'pcmcat276700050000': {'id': 'pcmcat276700050000',
#   'name': 'Computers & Tablets',
#   'count': 0,
#   'parent_id': 'pcmcat50000050006'},
#  'pcmcat275800050016': {'id': 'pcmcat275800050016',
#   'name': 'PS Vita Add-Ons',
#   'count': 0,
#   'parent_id': 'pcmcat243400050029'},
#  'pcmcat152100050022': {'id': 'pcmcat152100050022',
#   'name': 'Audio Interfaces',
#   'count': 339,
#   'parent_id': 'pcmcat152100050020'},
#  'pcmcat152100050023': {'id': 'pcmcat152100050023',
#   'name': 'Recorders',
#   'count': 206,
#   'parent_id': 'pcmcat152100050020'},
#  'pcmcat152100050032': {'id': 'pcmcat152100050032',
#   'name': 'DJ Lighting & Effects',
#   'count': 135,
#   'parent_id': 'pcmcat152100050027'},
#  'pcmcat152100050024': {'id': 'pcmcat152100050024',
#   'name': 'USB Mixers',
#   'count': 81,
#   'parent_id': 'pcmcat152100050020'},
#  'pcmcat253300050007': {'id': 'pcmcat253300050007',
#   'name': 'Music Software',
#   'count': 295,
#   'parent_id': 'abcat0508000'},
#  'pcmcat275800050015': {'id': 'pcmcat275800050015',
#   'name': 'PS Vita Game Downloads',
#   'count': 0,
#   'parent_id': 'pcmcat243400050029'},
#  'pcmcat275600050015': {'id': 'pcmcat275600050015',
#   'name': 'Philips Portable Video',
#   'count': 0,
#   'parent_id': 'pcmcat275600050012'},
#  'pcmcat152100050028': {'id': 'pcmcat152100050028',
#   'name': 'DJ CD Players',
#   'count': 28,
#   'parent_id': 'pcmcat152100050027'},
#  'pcmcat152100050029': {'id': 'pcmcat152100050029',
#   'name': 'DJ Mixers',
#   'count': 291,
#   'parent_id': 'pcmcat152100050027'},
#  'pcmcat152100050030': {'id': 'pcmcat152100050030',
#   'name': 'DJ Turntables',
#   'count': 132,
#   'parent_id': 'pcmcat152100050027'},
#  'pcmcat152100050025': {'id': 'pcmcat152100050025',
#   'name': 'Studio Monitors',
#   'count': 159,
#   'parent_id': 'pcmcat152100050020'},
#  'pcmcat230000050019': {'id': 'pcmcat230000050019',
#   'name': 'Brother Accessories & Supplies',
#   'count': 0,
#   'parent_id': 'pcmcat152600050013'},
#  'pcmcat152800050009': {'id': 'pcmcat152800050009',
#   'name': 'Brotherhood',
#   'count': 0,
#   'parent_id': 'pcmcat151700050000'},
#  'pcmcat152800050010': {'id': 'pcmcat152800050010',
#   'name': 'Californication',
#   'count': 0,
#   'parent_id': 'pcmcat151700050000'},
#  'pcmcat154300050002': {'id': 'pcmcat154300050002',
#   'name': 'Handheld & Stick Vacuums',
#   'count': 0,
#   'parent_id': 'pcmcat74600050004'},
#  'pcmcat154300050003': {'id': 'pcmcat154300050003',
#   'name': 'Upright Bagless Vacuums',
#   'count': 0,
#   'parent_id': 'pcmcat74600050004'},
#  'pcmcat154300050004': {'id': 'pcmcat154300050004',
#   'name': 'Canister Vacuums',
#   'count': 0,
#   'parent_id': 'pcmcat74600050004'},
#  'pcmcat154300050005': {'id': 'pcmcat154300050005',
#   'name': 'Steam Cleaners',
#   'count': 0,
#   'parent_id': 'pcmcat74600050004'},
#  'pcmcat154300050006': {'id': 'pcmcat154300050006',
#   'name': 'Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat74600050004'},
#  'pcmcat275100050014': {'id': 'pcmcat275100050014',
#   'name': 'Bosch Slide-in Ranges',
#   'count': 0,
#   'parent_id': 'pcmcat208400050010'},
#  'pcmcat154200050050': {'id': 'pcmcat154200050050',
#   'name': 'Frigidaire Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat154300050025': {'id': 'pcmcat154300050025',
#   'name': 'Upright Bagless Vacuums',
#   'count': 0,
#   'parent_id': 'pcmcat154300050024'},
#  'pcmcat154300050027': {'id': 'pcmcat154300050027',
#   'name': 'Canister Vacuums',
#   'count': 0,
#   'parent_id': 'pcmcat154300050024'},
#  'pcmcat154300050028': {'id': 'pcmcat154300050028',
#   'name': 'Steam Cleaners',
#   'count': 0,
#   'parent_id': 'pcmcat154300050024'},
#  'pcmcat154300050029': {'id': 'pcmcat154300050029',
#   'name': 'Hard Floor Cleaners',
#   'count': 0,
#   'parent_id': 'pcmcat154300050024'},
#  'pcmcat154300050030': {'id': 'pcmcat154300050030',
#   'name': 'Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat154300050024'},
#  'pcmcat154400050004': {'id': 'pcmcat154400050004',
#   'name': 'Software',
#   'count': 42,
#   'parent_id': 'pcmcat135300050050'},
#  'pcmcat154400050005': {'id': 'pcmcat154400050005',
#   'name': 'Hardware',
#   'count': 22,
#   'parent_id': 'pcmcat135300050050'},
#  'pcmcat154300050026': {'id': 'pcmcat154300050026',
#   'name': 'Upright Bag Vacuums',
#   'count': 0,
#   'parent_id': 'pcmcat154300050024'},
#  'pcmcat154200050029': {'id': 'pcmcat154200050029',
#   'name': 'Frigidaire Dehumidifiers',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat154200050027': {'id': 'pcmcat154200050027',
#   'name': 'Frigidaire Microwaves',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat154200050025': {'id': 'pcmcat154200050025',
#   'name': 'Frigidaire Dishwashers',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat152800050011': {'id': 'pcmcat152800050011',
#   'name': 'Dexter',
#   'count': 0,
#   'parent_id': 'pcmcat151700050000'},
#  'pcmcat152800050012': {'id': 'pcmcat152800050012',
#   'name': 'The Tudors',
#   'count': 0,
#   'parent_id': 'pcmcat151700050000'},
#  'pcmcat152800050013': {'id': 'pcmcat152800050013',
#   'name': 'Weeds',
#   'count': 0,
#   'parent_id': 'pcmcat151700050000'},
#  'pcmcat275600050006': {'id': 'pcmcat275600050006',
#   'name': 'Whiteboards & Presentation Supplies',
#   'count': 0,
#   'parent_id': 'pcmcat275600050000'},
#  'pcmcat275600050005': {'id': 'pcmcat275600050005',
#   'name': 'Desk Supplies & Fasteners',
#   'count': 0,
#   'parent_id': 'pcmcat275600050000'},
#  'pcmcat275600050004': {'id': 'pcmcat275600050004',
#   'name': 'Organizers & Storage',
#   'count': 0,
#   'parent_id': 'pcmcat275600050000'},
#  'pcmcat275600050003': {'id': 'pcmcat275600050003',
#   'name': 'Binders, Folders & Filing',
#   'count': 0,
#   'parent_id': 'pcmcat275600050000'},
#  'pcmcat153200050011': {'id': 'pcmcat153200050011',
#   'name': 'Frigidaire Refrigerators',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat275600050001': {'id': 'pcmcat275600050001',
#   'name': 'Pens, Pencils & Markers',
#   'count': 0,
#   'parent_id': 'pcmcat275600050000'},
#  'pcmcat153200050012': {'id': 'pcmcat153200050012',
#   'name': 'Frigidaire Freezers & Ice Makers',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat153200050013': {'id': 'pcmcat153200050013',
#   'name': 'Frigidaire Ranges & Ovens',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat153200050017': {'id': 'pcmcat153200050017',
#   'name': 'Frigidaire Washers & Dryers',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat275100050015': {'id': 'pcmcat275100050015',
#   'name': 'Bosch Laundry',
#   'count': 0,
#   'parent_id': 'pcmcat208400050010'},
#  'pcmcat153700050021': {'id': 'pcmcat153700050021',
#   'name': 'GPS Maps',
#   'count': 147,
#   'parent_id': 'abcat0301000'},
#  'pcmcat154200050013': {'id': 'pcmcat154200050013',
#   'name': 'Frigidaire Air Conditioners',
#   'count': 0,
#   'parent_id': 'pcmcat154200050001'},
#  'pcmcat154400050031': {'id': 'pcmcat154400050031',
#   'name': 'Mobile Phones & Office',
#   'count': 0,
#   'parent_id': 'pcmcat154200050035'},
#  'pcmcat188000050003': {'id': 'pcmcat188000050003',
#   'name': 'MP3 Diagnostic',
#   'count': 0,
#   'parent_id': 'pcmcat185200050009'},
#  'pcmcat190800050007': {'id': 'pcmcat190800050007',
#   'name': 'MinoHD',
#   'count': 0,
#   'parent_id': 'pcmcat190800050003'},
#  'pcmcat188600050033': {'id': 'pcmcat188600050033',
#   'name': 'Motorola Cordless Phones',
#   'count': 0,
#   'parent_id': 'pcmcat159400050006'},
#  'pcmcat230600050001': {'id': 'pcmcat230600050001',
#   'name': 'Laptops',
#   'count': 0,
#   'parent_id': 'pcmcat230600050000'},
#  'pcmcat230600050002': {'id': 'pcmcat230600050002',
#   'name': 'Netbooks',
#   'count': 0,
#   'parent_id': 'pcmcat230600050000'},
#  'pcmcat230600050003': {'id': 'pcmcat230600050003',
#   'name': 'Desktops',
#   'count': 0,
#   'parent_id': 'pcmcat230600050000'},
#  'pcmcat230600050004': {'id': 'pcmcat230600050004',
#   'name': 'Monitors',
#   'count': 0,
#   'parent_id': 'pcmcat230600050000'},
#  'pcmcat230600050005': {'id': 'pcmcat230600050005',
#   'name': 'Laptop Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat230600050000'},
#  'pcmcat230800050017': {'id': 'pcmcat230800050017',
#   'name': 'Racks, Mounts & Accessories',
#   'count': 167,
#   'parent_id': 'abcat0507000'},
#  'pcmcat257400050023': {'id': 'pcmcat257400050023',
#   'name': 'Lamps & Lighting',
#   'count': 0,
#   'parent_id': 'pcmcat249700050006'},
#  'pcmcat230800050019': {'id': 'pcmcat230800050019',
#   'name': 'Gaming Headsets',
#   'count': 1113,
#   'parent_id': 'abcat0715000'},
#  'pcmcat257100050034': {'id': 'pcmcat257100050034',
#   'name': 'Kidizoom',
#   'count': 0,
#   'parent_id': 'pcmcat248100050017'},
#  'pcmcat257100050031': {'id': 'pcmcat257100050031',
#   'name': 'Griffin Cables',
#   'count': 0,
#   'parent_id': 'pcmcat184000050001'},
#  'pcmcat257100050030': {'id': 'pcmcat257100050030',
#   'name': 'Griffin Screencare',
#   'count': 0,
#   'parent_id': 'pcmcat184000050001'},
#  'pcmcat231000050008': {'id': 'pcmcat231000050008',
#   'name': 'Marine Audio Accessories',
#   'count': 32,
#   'parent_id': 'pcmcat156300050010'},
#  'pcmcat231300050004': {'id': 'pcmcat231300050004',
#   'name': 'Netflix',
#   'count': 0,
#   'parent_id': 'pcmcat230800050018'},
#  'pcmcat231700050017': {'id': 'pcmcat231700050017',
#   'name': 'Smart Set-Top Boxes',
#   'count': 856,
#   'parent_id': 'abcat0103000'},
#  'pcmcat257300050005': {'id': 'pcmcat257300050005',
#   'name': 'Windows Phone',
#   'count': 0,
#   'parent_id': 'pcmcat135300050050'},
#  'pcmcat230500050000': {'id': 'pcmcat230500050000',
#   'name': 'TV & Video Accessories',
#   'count': 0,
#   'parent_id': 'pcmcat192300050018'},
#  'pcmcat230000050018': {'id': 'pcmcat230000050018',
#   'name': 'Brother Labelers & Laminators',
#   'count': 0,
#   'parent_id': 'pcmcat152600050013'},
#  'pcmcat230000050017': {'id': 'pcmcat230000050017',
#   'name': 'Brother Printers',
#   'count': 0,
#   'parent_id': 'pcmcat152600050013'},
#  'pcmcat227500050048': {'id': 'pcmcat227500050048',
#   'name': 'Motherboards',
#   'count': 0,
#   'parent_id': 'pcmcat190000050006'},
#  'pcmcat227500050049': {'id': 'pcmcat227500050049',
#   'name': 'Video Graphic Cards',
#   'count': 0,
#   'parent_id': 'pcmcat190000050006'},
#  'pcmcat227500050050': {'id': 'pcmcat227500050050',
#   'name': 'External DVD Drives',
#   'count': 0,
#   'parent_id': 'pcmcat190000050006'},
#  ...}

# %%
queries_df_with_query_count_dedupped = queries_df_with_query_count.drop(['user', 'sku', 'Unnamed: 0', 'id', 'query'], axis=1).drop_duplicates()
queries_df_with_query_count_dedupped
# Out:
#                    category               query_normalized  query_count  \
# 0              abcat0101001  television panason 50 pulgada        11437
# 1              abcat0101001                          sharp        11437
# 2              abcat0101001                            rca        11437
# 3              abcat0101001                     samsung 40        11437
# 4              abcat0101001                         lcd tv        11437
# ...                     ...                            ...          ...
# 1847442  pcmcat235500050003                      3ds bundl            1
# 1847443  pcmcat240500050027                   camera light            1
# 1847444  pcmcat235500050005                    portabl dvv            1
# 1847445            cat02737                           drum            1
# 1847446  pcmcat221400050013                  gen 16 cymbal            1
#
#                              name           parent_id           parent_name  \
# 0              All Flat-Panel TVs        abcat0101000                   TVs
# 1              All Flat-Panel TVs        abcat0101000                   TVs
# 2              All Flat-Panel TVs        abcat0101000                   TVs
# 3              All Flat-Panel TVs        abcat0101000                   TVs
# 4              All Flat-Panel TVs        abcat0101000                   TVs
# ...                           ...                 ...                   ...
# 1847442     Nintendo 3DS Consoles  pcmcat232900050000          Nintendo 3DS
# 1847443                 Softboxes  pcmcat240500050025  Photography Lighting
# 1847444  Nintendo 3DS Accessories  pcmcat232900050000          Nintendo 3DS
# 1847445                  Buddhist            cat02014                 World
# 1847446        Electronic Cymbals  pcmcat152100050012               Cymbals
#
#          depth
# 0            4
# 1            4
# 2            4
# 3            4
# 4            4
# ...        ...
# 1847442      4
# 1847443      7
# 1847444      4
# 1847445      5
# 1847446      5
#
# [320153 rows x 7 columns]

# %%
queries_df_with_query_count_dedupped_with_rollup = queries_df_with_query_count_dedupped.merge(rollup_df, left_on='category', right_on='from_category_id', how='inner').sort_values(by='category')

queries_df_with_query_count_dedupped_with_rollup
# Out:
#                  category               query_normalized  query_count  \
# 281122       abcat0020004                       cellphon            3
# 281123       abcat0020004                     cell phone            3
# 281124       abcat0020004                 beverag center            3
# 0            abcat0101001  television panason 50 pulgada        11437
# 7621         abcat0101001                      panson 3d        11437
# ...                   ...                            ...          ...
# 279226  pcmcat99000050002                        8339283           12
# 279230  pcmcat99000050002                      dsl modem           12
# 279229  pcmcat99000050002                    router wire           12
# 279227  pcmcat99000050002                ethernet router           12
# 279231  pcmcat99000050002               broadband router           12
#
#                       name          parent_id  parent_name  depth  \
# 281122        Unique Gifts       abcat0010000  Gift Center      3
# 281123        Unique Gifts       abcat0010000  Gift Center      3
# 281124        Unique Gifts       abcat0010000  Gift Center      3
# 0       All Flat-Panel TVs       abcat0101000          TVs      4
# 7621    All Flat-Panel TVs       abcat0101000          TVs      4
# ...                    ...                ...          ...    ...
# 279226    Dynex Networking  pcmcat99000050001   Networking      5
# 279230    Dynex Networking  pcmcat99000050001   Networking      5
# 279229    Dynex Networking  pcmcat99000050001   Networking      5
# 279227    Dynex Networking  pcmcat99000050001   Networking      5
# 279231    Dynex Networking  pcmcat99000050001   Networking      5
#
#          from_category_id  from_category_name  count      to_category_id  \
# 281122       abcat0020004        Unique Gifts      3            cat00000
# 281123       abcat0020004        Unique Gifts      3            cat00000
# 281124       abcat0020004        Unique Gifts      3            cat00000
# 0            abcat0101001  All Flat-Panel TVs  11437        abcat0101001
# 7621         abcat0101001  All Flat-Panel TVs  11437        abcat0101001
# ...                   ...                 ...    ...                 ...
# 279226  pcmcat99000050002    Dynex Networking     12  pcmcat128500050004
# 279230  pcmcat99000050002    Dynex Networking     12  pcmcat128500050004
# 279229  pcmcat99000050002    Dynex Networking     12  pcmcat128500050004
# 279227  pcmcat99000050002    Dynex Networking     12  pcmcat128500050004
# 279231  pcmcat99000050002    Dynex Networking     12  pcmcat128500050004
#
#           to_category_name
# 281122            Best Buy
# 281123            Best Buy
# 281124            Best Buy
# 0       All Flat-Panel TVs
# 7621    All Flat-Panel TVs
# ...                    ...
# 279226         Name Brands
# 279230         Name Brands
# 279229         Name Brands
# 279227         Name Brands
# 279231         Name Brands
#
# [281827 rows x 12 columns]

# %%
queries_df_with_query_count_dedupped_with_rollup[queries_df_with_query_count_dedupped_with_rollup['category'] == 'pcmcat171900050029']
# Out:
#                   category            query_normalized  query_count    name  \
# 103471  pcmcat171900050029       blackberri torch case         3992  Fitted
# 103481  pcmcat171900050029                   laptop 17         3992  Fitted
# 103482  pcmcat171900050029                      belkin         3992  Fitted
# 106529  pcmcat171900050029                      evo 3g         3992  Fitted
# 106530  pcmcat171900050029         tdident cyclop case         3992  Fitted
# ...                    ...                         ...          ...     ...
# 105432  pcmcat171900050029              lifeproof case         3992  Fitted
# 105431  pcmcat171900050029                      d link         3992  Fitted
# 105429  pcmcat171900050029                     desir s         3992  Fitted
# 106895  pcmcat171900050029  motorolla atrix phone case         3992  Fitted
# 106158  pcmcat171900050029       otterbox iphon commut         3992  Fitted
#
#            parent_id                 parent_name  depth    from_category_id  \
# 103471  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 103481  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 103482  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 106529  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 106530  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# ...              ...                         ...    ...                 ...
# 105432  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 105431  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 105429  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 106895  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
# 106158  abcat0811006  Mobile Phone Cases & Clips      5  pcmcat171900050029
#
#        from_category_name  count      to_category_id to_category_name
# 103471             Fitted   3992  pcmcat171900050029           Fitted
# 103481             Fitted   3992  pcmcat171900050029           Fitted
# 103482             Fitted   3992  pcmcat171900050029           Fitted
# 106529             Fitted   3992  pcmcat171900050029           Fitted
# 106530             Fitted   3992  pcmcat171900050029           Fitted
# ...                   ...    ...                 ...              ...
# 105432             Fitted   3992  pcmcat171900050029           Fitted
# 105431             Fitted   3992  pcmcat171900050029           Fitted
# 105429             Fitted   3992  pcmcat171900050029           Fitted
# 106895             Fitted   3992  pcmcat171900050029           Fitted
# 106158             Fitted   3992  pcmcat171900050029           Fitted
#
# [3993 rows x 12 columns]

# %%
# %env FASTTEXT_LABEL_FILE $WEEK4 + '/data/query_classification.fasttext'
FASTTEXT_LABEL_FILE = WEEK4 + '/data/query_classification.fasttext'

# %env FASTTEXT_LABEL_FILE_SHUFFLED $WEEK4 + '/data/query_classification_shuffled.fasttext'
FASTTEXT_LABEL_FILE_SHUFFLED = WEEK4 + '/data/query_classification_shuffled.fasttext'

# %env FASTTEXT_LABEL_FILE_TRAINING $WEEK4 + '/data/query_classification_train.fasttext'
FASTTEXT_LABEL_FILE_TRAINING = WEEK4 + '/data/query_classification_train.fasttext'

# %env FASTTEXT_LABEL_FILE_TEST $WEEK4 + '/data/query_classification_test.fasttext'
FASTTEXT_LABEL_FILE_TEST = WEEK4 + '/data/query_classification_test.fasttext'





queries_df_with_query_count_dedupped_with_rollup_shuffled = queries_df_with_query_count_dedupped_with_rollup.sample(frac=1)

desired_entries = queries_df_with_query_count_dedupped_with_rollup_shuffled.shape[0]
head_size = math.ceil(desired_entries * .75)
tail_size = math.ceil(desired_entries * .20)

fasttext_train_df = queries_df_with_query_count_dedupped_with_rollup_shuffled.head(head_size)
#.sample(frac=1)
fasttext_test_df = queries_df_with_query_count_dedupped_with_rollup_shuffled.tail(tail_size)
#.sample(frac=1)
# making sure there's no overlap data between train and test data
#fasttext_test_df = fasttext_test_df[~fasttext_test_df.isin(fasttext_train_df)].dropna()
#.sample(frac=1)

print(
f'Generating training data: \n' +
f'  head_size: {head_size}\n' +
f'  tail_size: {tail_size}\n' +
f'  fasttext_train_df #rows: {fasttext_train_df.shape[0]}\n' +
f'  fasttext_test_df #rows: {fasttext_test_df.shape[0]}\n'
)



with open(FASTTEXT_LABEL_FILE_TRAINING, 'w') as file:
    for index, row in fasttext_train_df.iterrows():
        fasttext_row = f"__label__{row['to_category_id']} {row['query_normalized']}"
        file.write(fasttext_row + '\n')

with open(FASTTEXT_LABEL_FILE_TEST, 'w') as file:
    for index, row in fasttext_test_df.iterrows():
        fasttext_row = f"__label__{row['to_category_id']} {row['query_normalized']}"
        file.write(fasttext_row + '\n')
# Out:
# env: FASTTEXT_LABEL_FILE=/workspace/search_with_machine_learning_course/week4 + '/data/query_classification.fasttext'
# env: FASTTEXT_LABEL_FILE_SHUFFLED=/workspace/search_with_machine_learning_course/week4 + '/data/query_classification_shuffled.fasttext'
# env: FASTTEXT_LABEL_FILE_TRAINING=/workspace/search_with_machine_learning_course/week4 + '/data/query_classification_train.fasttext'
# env: FASTTEXT_LABEL_FILE_TEST=/workspace/search_with_machine_learning_course/week4 + '/data/query_classification_test.fasttext'
# Generating training data:
#   head_size: 211371
#   tail_size: 56366
#   fasttext_train_df #rows: 211371
#   fasttext_test_df #rows: 56366

# %%
!~/fastText-0.9.2/fasttext supervised \
    -input $FASTTEXT_LABEL_FILE_TRAINING \
    -output $WEEK4/data/query-classifier-model \
    -epoch 25 \
    -lr .05 \
    -loss hs \
    -wordNgrams 2
# Out:
# Read 0M words
# Number of words:  39993
# Number of labels: 158
# Progress: 100.0% words/sec/thread:   32292 lr:  0.000000 avg.loss:  2.165621 ETA:   0h 0m 0s  0h 0m54s36s lr:  0.027545 avg.loss:  2.722070 ETA:   0h 0m33s 2.659781 ETA:   0h 0m30sm22s  0h 0m 2s

# %%
!~/fastText-0.9.2/fasttext test \
    $WEEK4/data/query-classifier-model.bin \
    $FASTTEXT_LABEL_FILE_TEST

print('')    

!~/fastText-0.9.2/fasttext test \
    $WEEK4/data/query-classifier-model.bin \
    $FASTTEXT_LABEL_FILE_TEST \
    3
print('')

!~/fastText-0.9.2/fasttext test \
    $WEEK4/data/query-classifier-model.bin \
    $FASTTEXT_LABEL_FILE_TEST \
    5
# Out:
# N	56366
# P@1	0.332
# R@1	0.332
#
# N	56366
# P@3	0.166
# R@3	0.499
#
# N	56366
# P@5	0.113
# R@5	0.563

# %%
import fasttext
import functions


inputs = ['iphone', 'ipad', 'apple iphone', 'playstation 3', 'age of empires', 'sharp tv', 'haystack']

number_of_predictions = 5
model = fasttext.load_model(WEEK4 + '/data/query-classifier-model.bin')

for input in inputs:
    input_stemmed = functions.transform_name(input)

    print(f"predition for {input} / stemmed: {input_stemmed}:")
    (predictions, scores) = model.predict(input_stemmed, k=number_of_predictions)

    i=0
    for prediction in predictions:    
        label = prediction.split('__')[2]
        node = cat_nodes[label]
        print(f"{label} - {node.data['name']} ({node.data['count']}):{scores[i]}")
        #grep_output = os.popen(f'grep -iRh {lable} -A 1 /workspace/datasets/product_data/categories | tail -n 1 | sed -e \'s/<[^>]*>//g\'').read()
        #print(grep_output.strip())
        i = i+1
    print('\n')
# Out:
# predition for iphone / stemmed: iphon:
# pcmcat191200050015 - iPhone Accessories (2200):0.043403368443250656
# abcat0208011 - iPod & MP3 Speakers, Docks & Radios (1827):0.037946850061416626
# pcmcat248700050021 - Home (3703):0.037323445081710815
# abcat0307005 - Car Accessories (3348):0.03704296052455902
# abcat0300000 - Car, Marine & GPS (6805):0.0349414125084877
#
#
# predition for ipad / stemmed: ipad:
# pcmcat231800050009 - Tablet Accessories (3564):0.07089034467935562
# pcmcat209000050007 - iPad (1762):0.06924150884151459
# pcmcat217900050000 - iPad Accessories (3164):0.05312281847000122
# pcmcat230600050006 - Sports Fan Shop (1001):0.03462045639753342
# pcmcat248700050021 - Home (3703):0.03370543569326401
#
#
# predition for apple iphone / stemmed: appl iphon:
# pcmcat209400050001 - All Mobile Phones with Plans (4907):0.17464517056941986
# pcmcat201900050009 - Screen Protectors (1371):0.0925264060497284
# abcat0800000 - Mobile Phones (25818):0.07401757687330246
# abcat0208007 - iPod & MP3 Player Accessories (2902):0.052892930805683136
# pcmcat171900050029 - Fitted (3992):0.043786462396383286
#
#
# predition for playstation 3 / stemmed: playstat 3:
# abcat0703001 - PS3 Consoles (1040):0.15680861473083496
# abcat0703000 - PlayStation 3 (2109):0.12835147976875305
# abcat0700000 - Video Games (9888):0.06432142853736877
# abcat0302019 - Satellite Radios (1781):0.045173171907663345
# pcmcat209400050001 - All Mobile Phones with Plans (4907):0.03697587177157402
#
#
# predition for age of empires / stemmed: age of empir:
# pcmcat174700050005 - PC Games (1979):0.7140664458274841
# pcmcat247400050000 - PC Laptops (11953):0.12520672380924225
# pcmcat232900050017 - Pre-Owned Games (2802):0.06278996169567108
# cat02015 - Movies & TV Shows (22905):0.047482896596193314
# pcmcat209400050001 - All Mobile Phones with Plans (4907):0.015819257125258446
#
#
# predition for sharp tv / stemmed: sharp tv:
# abcat0101000 - TVs (12129):0.2076147198677063
# abcat0102000 - Blu-ray & DVD Players (1766):0.1588016003370285
# abcat0101001 - All Flat-Panel TVs (11437):0.09067738056182861
# abcat0900000 - Appliances (20851):0.08322571218013763
# pcmcat158900050008 - Projectors & Screens (1222):0.07396620512008667
#
#
# predition for haystack / stemmed: haystack:
# cat02015 - Movies & TV Shows (22905):0.4524732828140259
# abcat0101001 - All Flat-Panel TVs (11437):0.08284122496843338
# pcmcat247400050000 - PC Laptops (11953):0.05037987604737282
# pcmcat209400050001 - All Mobile Phones with Plans (4907):0.03326142951846123
# cat02001 - Music (12475):0.029393300414085388
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# Out:
# {'cat00000': <__main__.Node at 0x7f60cd1ad340>,
#  'abcat0100000': <__main__.Node at 0x7f60da89aeb0>,
#  'pcmcat245100050028': <__main__.Node at 0x7f60da89af10>,
#  'abcat0800000': <__main__.Node at 0x7f60cc7bcfd0>,
#  'abcat0300000': <__main__.Node at 0x7f60cc7bc250>,
#  'pcmcat149900050025': <__main__.Node at 0x7f60cc7bcb80>,
#  'pcmcat133600050011': <__main__.Node at 0x7f60cc7bc340>,
#  'abcat0600000': <__main__.Node at 0x7f60cc7be0d0>,
#  'abcat0200000': <__main__.Node at 0x7f60cc7bec40>,
#  'pcmcat248000050016': <__main__.Node at 0x7f60cc7bef40>,
#  'abcat0700000': <__main__.Node at 0x7f60cc7be850>,
#  'pcmcat248700050021': <__main__.Node at 0x7f60cc7be820>,
#  'pcmcat164600050001': <__main__.Node at 0x7f60cc7be520>,
#  'pcmcat128500050004': <__main__.Node at 0x7f60cc7be2e0>,
#  'pcmcat230000050010': <__main__.Node at 0x7f60cc7bee50>,
#  'pcmcat102500050032': <__main__.Node at 0x7f60cc7bedc0>,
#  'pcmcat159800050001': <__main__.Node at 0x7f60cc7be3d0>,
#  'pcmcat226500050012': <__main__.Node at 0x7f60cc7bea30>,
#  'cat09000': <__main__.Node at 0x7f60cc7be970>,
#  'abcat0400000': <__main__.Node at 0x7f60cd2407f0>,
#  'pcmcat254400050000': <__main__.Node at 0x7f60cd240d60>,
#  'abcat0900000': <__main__.Node at 0x7f60cd240550>,
#  'pcmcat142300050026': <__main__.Node at 0x7f60cd2403a0>,
#  'abcat0010000': <__main__.Node at 0x7f60cd240580>,
#  'pcmcat242800050021': <__main__.Node at 0x7f60cd240d90>,
#  'pcmcat200300050008': <__main__.Node at 0x7f60cd2402e0>,
#  'pcmcat253300050001': <__main__.Node at 0x7f60cd240220>,
#  'abcat0500000': <__main__.Node at 0x7f60cd240490>,
#  'pcmcat230900050001': <__main__.Node at 0x7f60cd240970>,
#  'pcmcat138100050018': <__main__.Node at 0x7f60cd240a30>,
#  'pcmcat87800050001': <__main__.Node at 0x7f60cd240370>,
#  'abcat0207000': <__main__.Node at 0x7f60cd240ac0>,
#  'pcmcat139900050002': <__main__.Node at 0x7f60cd240340>,
#  'pcmcat203600050025': <__main__.Node at 0x7f60cd009340>,
#  'pcmcat230800050018': <__main__.Node at 0x7f60cd240310>,
#  'pcmcat212100050006': <__main__.Node at 0x7f60cd240190>,
#  'pcmcat211900050000': <__main__.Node at 0x7f60cd2409a0>,
#  'abcat0902000': <__main__.Node at 0x7f60cd240250>,
#  'abcat0903000': <__main__.Node at 0x7f60cd240100>,
#  'pcmcat196200050018': <__main__.Node at 0x7f60cd240b20>,
#  'abcat0904000': <__main__.Node at 0x7f60cd240be0>,
#  'pcmcat196700050004': <__main__.Node at 0x7f60cd240640>,
#  'pcmcat211000050003': <__main__.Node at 0x7f60cd240460>,
#  'abcat0901000': <__main__.Node at 0x7f610e5716d0>,
#  'abcat0809000': <__main__.Node at 0x7f610e571f70>,
#  'pcmcat214000050005': <__main__.Node at 0x7f610e571910>,
#  'abcat0905000': <__main__.Node at 0x7f610e571490>,
#  'abcat0714000': <__main__.Node at 0x7f610e5714c0>,
#  'pcmcat252700050006': <__main__.Node at 0x7f610e571070>,
#  'pcmcat221600050000': <__main__.Node at 0x7f610e571c10>,
#  'pcmcat220400050001': <__main__.Node at 0x7f610e571130>,
#  'abcat0801002': <__main__.Node at 0x7f60cd167c40>,
#  'abcat0802000': <__main__.Node at 0x7f60cd167730>,
#  'pcmcat213800050001': <__main__.Node at 0x7f60cd167e50>,
#  'pcmcat217800050001': <__main__.Node at 0x7f60cd167760>,
#  'pcmcat214700050032': <__main__.Node at 0x7f60cd167490>,
#  'pcmcat214100050018': <__main__.Node at 0x7f60cd167fa0>,
#  'abcat0808000': <__main__.Node at 0x7f60cd1678b0>,
#  'pcmcat214100050013': <__main__.Node at 0x7f60cd167f70>,
#  'pcmcat195500050023': <__main__.Node at 0x7f60cd167f10>,
#  'pcmcat195600050002': <__main__.Node at 0x7f60cd167be0>,
#  'abcat0807000': <__main__.Node at 0x7f60cd167fd0>,
#  'abcat0906000': <__main__.Node at 0x7f60cd167880>,
#  'abcat0907000': <__main__.Node at 0x7f60cd167100>,
#  'cat02015': <__main__.Node at 0x7f60cd167e80>,
#  'pcmcat208100050003': <__main__.Node at 0x7f60cd1675b0>,
#  'pcmcat208100050002': <__main__.Node at 0x7f60cd167a00>,
#  'pcmcat208100050001': <__main__.Node at 0x7f60cd167400>,
#  'pcmcat205700050020': <__main__.Node at 0x7f60cd167dc0>,
#  'pcmcat253700050020': <__main__.Node at 0x7f60cd1671c0>,
#  'pcmcat205600050012': <__main__.Node at 0x7f60cd1679d0>,
#  'pcmcat208100050004': <__main__.Node at 0x7f60cd1670d0>,
#  'pcmcat243800050004': <__main__.Node at 0x7f60cd167b80>,
#  'pcmcat205600050010': <__main__.Node at 0x7f60cd1677f0>,
#  'pcmcat205300050001': <__main__.Node at 0x7f60cd167850>,
#  'pcmcat203400050001': <__main__.Node at 0x7f60cd1677c0>,
#  'abcat0916006': <__main__.Node at 0x7f60cd167190>,
#  'pcmcat204200050016': <__main__.Node at 0x7f60cd1673d0>,
#  'abcat0916000': <__main__.Node at 0x7f60cd167e20>,
#  'pcmcat205600050011': <__main__.Node at 0x7f60cd167b20>,
#  'pcmcat210800050014': <__main__.Node at 0x7f60cd167340>,
#  'pcmcat208400050010': <__main__.Node at 0x7f60cd1676d0>,
#  'abcat0912001': <__main__.Node at 0x7f60cd167580>,
#  'pcmcat203500050000': <__main__.Node at 0x7f60cd167310>,
#  'pcmcat210600050000': <__main__.Node at 0x7f60cd167640>,
#  'pcmcat210400050001': <__main__.Node at 0x7f60cd167040>,
#  'pcmcat200900050008': <__main__.Node at 0x7f60cd167670>,
#  'abcat0908000': <__main__.Node at 0x7f610e640d30>,
#  'abcat0909000': <__main__.Node at 0x7f610e640430>,
#  'pcmcat208600050001': <__main__.Node at 0x7f610e640e80>,
#  'abcat0910000': <__main__.Node at 0x7f610e6404c0>,
#  'abcat0911000': <__main__.Node at 0x7f610e640d90>,
#  'abcat0713000': <__main__.Node at 0x7f610e640dc0>,
#  'pcmcat209400050001': <__main__.Node at 0x7f610e6406d0>,
#  'pcmcat209000050006': <__main__.Node at 0x7f610e6409a0>,
#  'cat02001': <__main__.Node at 0x7f610e640f10>,
#  'abcat0912000': <__main__.Node at 0x7f610e640b80>,
#  'pcmcat209800050001': <__main__.Node at 0x7f610e640610>,
#  'abcat0712000': <__main__.Node at 0x7f610e640a90>,
#  'pcmcat226400050024': <__main__.Node at 0x7f610e640160>,
#  'pcmcat222000050000': <__main__.Node at 0x7f610e640790>,
#  'pcmcat246900050017': <__main__.Node at 0x7f610e640280>,
#  'pcmcat246300050007': <__main__.Node at 0x7f610e640550>,
#  'pcmcat246100050003': <__main__.Node at 0x7f610e640fd0>,
#  'abcat0508000': <__main__.Node at 0x7f610e640970>,
#  'abcat0508003': <__main__.Node at 0x7f610e640c10>,
#  'pcmcat243500050029': <__main__.Node at 0x7f610e640070>,
#  'pcmcat243400050029': <__main__.Node at 0x7f610e640700>,
#  'pcmcat243400050026': <__main__.Node at 0x7f610e640c70>,
#  'pcmcat251300050011': <__main__.Node at 0x7f610e640ac0>,
#  'abcat0509000': <__main__.Node at 0x7f610e640250>,
#  'abcat0510000': <__main__.Node at 0x7f610e640640>,
#  'abcat0511000': <__main__.Node at 0x7f610e6ab670>,
#  'abcat0511001': <__main__.Node at 0x7f610e6ab5e0>,
#  'pcmcat241100050019': <__main__.Node at 0x7f610e6ab340>,
#  'abcat0511006': <__main__.Node at 0x7f610e6ab460>,
#  'pcmcat246900050018': <__main__.Node at 0x7f610e6abdc0>,
#  'abcat0511007': <__main__.Node at 0x7f610e6abeb0>,
#  'abcat0504010': <__main__.Node at 0x7f610e6aba00>,
#  'abcat0504000': <__main__.Node at 0x7f610e6ab490>,
#  'pcmcat252500050045': <__main__.Node at 0x7f610e6abc10>,
#  'pcmcat252500050041': <__main__.Node at 0x7f610e6ab790>,
#  'pcmcat251300050009': <__main__.Node at 0x7f610e6ab280>,
#  'abcat0501000': <__main__.Node at 0x7f610e6ab8e0>,
#  'pcmcat250600050010': <__main__.Node at 0x7f610e6ab430>,
#  'abcat0502000': <__main__.Node at 0x7f610e6abf40>,
#  'pcmcat254300050005': <__main__.Node at 0x7f610e6ab070>,
#  'abcat0503000': <__main__.Node at 0x7f610e6aba90>,
#  'pcmcat154200050035': <__main__.Node at 0x7f610e6abe80>,
#  'pcmcat249300050012': <__main__.Node at 0x7f610e6abd60>,
#  'pcmcat249000050000': <__main__.Node at 0x7f610e6ab7f0>,
#  'pcmcat248300050015': <__main__.Node at 0x7f610e6ab550>,
#  'abcat0507000': <__main__.Node at 0x7f610e6abdf0>,
#  'pcmcat253700050018': <__main__.Node at 0x7f610e6ab0d0>,
#  'pcmcat248100050017': <__main__.Node at 0x7f610e6ab0a0>,
#  'abcat0504001': <__main__.Node at 0x7f610e6ab4c0>,
#  'abcat0711000': <__main__.Node at 0x7f610e6ab910>,
#  'abcat0511011': <__main__.Node at 0x7f610e6ab8b0>,
#  'abcat0513000': <__main__.Node at 0x7f610e6ab580>,
#  'pcmcat230000050013': <__main__.Node at 0x7f610e6abee0>,
#  'pcmcat153600050007': <__main__.Node at 0x7f610e6ab400>,
#  'pcmcat270900050006': <__main__.Node at 0x7f610e6ab130>,
#  'abcat0703000': <__main__.Node at 0x7f610e6ab310>,
#  'pcmcat229000050002': <__main__.Node at 0x7f610e6abd30>,
#  'pcmcat227000050000': <__main__.Node at 0x7f610e6abc40>,
#  'pcmcat195400050017': <__main__.Node at 0x7f610e6ab610>,
#  'pcmcat273800050017': <__main__.Node at 0x7f610e6abbe0>,
#  'abcat0705000': <__main__.Node at 0x7f610e6ab760>,
#  'pcmcat224100050004': <__main__.Node at 0x7f610e6abe20>,
#  'abcat0706000': <__main__.Node at 0x7f610e6ab160>,
#  'pcmcat223500050003': <__main__.Node at 0x7f610e6ab880>,
#  'abcat0707000': <__main__.Node at 0x7f610e3426d0>,
#  'pcmcat223200050005': <__main__.Node at 0x7f610e342c40>,
#  'pcmcat222200050000': <__main__.Node at 0x7f610e342820>,
#  'pcmcat230600050000': <__main__.Node at 0x7f610e342c10>,
#  'abcat0805000': <__main__.Node at 0x7f610e342250>,
#  'pcmcat135300050050': <__main__.Node at 0x7f610e342dc0>,
#  'abcat0603000': <__main__.Node at 0x7f610e342a90>,
#  'pcmcat239700050008': <__main__.Node at 0x7f610e342fa0>,
#  'pcmcat239100050009': <__main__.Node at 0x7f610e342cd0>,
#  'pcmcat238900050009': <__main__.Node at 0x7f610e342eb0>,
#  'pcmcat238300050021': <__main__.Node at 0x7f610e342a60>,
#  'abcat0515000': <__main__.Node at 0x7f610e342520>,
#  'pcmcat244200050008': <__main__.Node at 0x7f610e342f70>,
#  'abcat0715000': <__main__.Node at 0x7f610e342af0>,
#  'pcmcat234900050002': <__main__.Node at 0x7f610e3426a0>,
#  'pcmcat234000050008': <__main__.Node at 0x7f610e342a00>,
#  'pcmcat233100050008': <__main__.Node at 0x7f610e342970>,
#  'abcat0811000': <__main__.Node at 0x7f610e342550>,
#  'pcmcat232900050010': <__main__.Node at 0x7f610e342d90>,
#  'pcmcat232900050000': <__main__.Node at 0x7f610e342670>,
#  'pcmcat231900050003': <__main__.Node at 0x7f610e3427c0>,
#  'abcat0602000': <__main__.Node at 0x7f610e342880>,
#  'abcat0604000': <__main__.Node at 0x7f610e3421f0>,
#  'pcmcat195200050008': <__main__.Node at 0x7f610e342e50>,
#  'pcmcat190800050009': <__main__.Node at 0x7f610e342f10>,
#  'pcmcat194500050008': <__main__.Node at 0x7f610e342610>,
#  'pcmcat152100050010': <__main__.Node at 0x7f610e3427f0>,
#  'pcmcat128500050005': <__main__.Node at 0x7f610e3428e0>,
#  'pcmcat151900050007': <__main__.Node at 0x7f610e3428b0>,
#  'pcmcat151700050000': <__main__.Node at 0x7f610e342e20>,
#  'pcmcat132700050016': <__main__.Node at 0x7f610e342fd0>,
#  'pcmcat151600050037': <__main__.Node at 0x7f60da8cca30>,
#  'pcmcat133000050031': <__main__.Node at 0x7f60da8cc070>,
#  'pcmcat127000050003': <__main__.Node at 0x7f60da8cc1c0>,
#  'pcmcat151600050019': <__main__.Node at 0x7f60da8ccd60>,
#  'pcmcat151600050002': <__main__.Node at 0x7f60da8cc460>,
#  'pcmcat151300050000': <__main__.Node at 0x7f60da8cc580>,
#  'pcmcat134600050009': <__main__.Node at 0x7f60da8cc910>,
#  'pcmcat134600050010': <__main__.Node at 0x7f60da8cc3a0>,
#  'pcmcat151000050010': <__main__.Node at 0x7f60da8ccca0>,
#  'pcmcat150300050000': <__main__.Node at 0x7f60da8cc400>,
#  'pcmcat149900050041': <__main__.Node at 0x7f60da8cc550>,
#  'pcmcat133100050006': <__main__.Node at 0x7f60da8ccfa0>,
#  'pcmcat149900050022': <__main__.Node at 0x7f60da8ccb20>,
#  'pcmcat123000050004': <__main__.Node at 0x7f60da8cc130>,
#  'pcmcat50000050006': <__main__.Node at 0x7f60da8cc5e0>,
#  'pcmcat154300050024': <__main__.Node at 0x7f60da8cc280>,
#  'pcmcat74600050004': <__main__.Node at 0x7f60da8ccee0>,
#  'pcmcat153600050014': <__main__.Node at 0x7f60da8cc340>,
#  'pcmcat153400050000': <__main__.Node at 0x7f60da8cc760>,
#  'pcat17093': <__main__.Node at 0x7f60da8ccdf0>,
#  'pcmcat154200050001': <__main__.Node at 0x7f60da8cc9d0>,
#  'pcmcat102800050018': <__main__.Node at 0x7f60da8ccc70>,
#  'pcmcat152100050020': <__main__.Node at 0x7f60da8cc8e0>,
#  'pcmcat103600050007': <__main__.Node at 0x7f60da8cce80>,
#  'pcmcat152600050013': <__main__.Node at 0x7f60da8cceb0>,
#  'pcmcat152600050004': <__main__.Node at 0x7f60da8ccc10>,
#  'pcmcat152200050014': <__main__.Node at 0x7f60da8cc520>,
#  'pcmcat111900050004': <__main__.Node at 0x7f60da8ccaf0>,
#  'pcmcat152100050035': <__main__.Node at 0x7f60da8ccd00>,
#  'pcmcat84000050003': <__main__.Node at 0x7f60da8cc820>,
#  'pcmcat152100050027': <__main__.Node at 0x7f60da8cc430>,
#  'pcmcat110200050031': <__main__.Node at 0x7f60da8cc220>,
#  'pcmcat154500050003': <__main__.Node at 0x7f610e6adbb0>,
#  'pcmcat135200050014': <__main__.Node at 0x7f610e6ad280>,
#  'pcmcat147200050008': <__main__.Node at 0x7f610e6adeb0>,
#  'pcmcat140900050016': <__main__.Node at 0x7f610e6adac0>,
#  'pcmcat137700050018': <__main__.Node at 0x7f610e6ad580>,
#  'pcmcat140800050115': <__main__.Node at 0x7f610e6ad400>,
#  'pcmcat140500050010': <__main__.Node at 0x7f610e6adb80>,
#  'pcmcat140000050042': <__main__.Node at 0x7f610e6ada90>,
#  'pcmcat140000050041': <__main__.Node at 0x7f610e6ad820>,
#  'pcmcat138100050024': <__main__.Node at 0x7f610e6ad3a0>,
#  'pcmcat142400050015': <__main__.Node at 0x7f610e6ad5b0>,
#  'pcmcat138100050025': <__main__.Node at 0x7f610e6ad5e0>,
#  'pcmcat140000050039': <__main__.Node at 0x7f610e6ad8e0>,
#  'pcmcat140000050037': <__main__.Node at 0x7f610e6ad6d0>,
#  'pcmcat140000050036': <__main__.Node at 0x7f610e6ad7c0>,
#  'pcmcat140000050035': <__main__.Node at 0x7f610e6ad910>,
#  'pcmcat140000050019': <__main__.Node at 0x7f610e6add30>,
#  'pcmcat139900050006': <__main__.Node at 0x7f610e6ad460>,
#  'pcmcat138900050012': <__main__.Node at 0x7f610e6ad6a0>,
#  'pcmcat140000050040': <__main__.Node at 0x7f610e6ad0a0>,
#  'pcmcat149000050005': <__main__.Node at 0x7f610e6ad3d0>,
#  'pcmcat137400050055': <__main__.Node at 0x7f610e6adfd0>,
#  'pcmcat143000050025': <__main__.Node at 0x7f610e6ada30>,
#  'pcmcat145500050036': <__main__.Node at 0x7f610e6ad670>,
#  'pcmcat135300050002': <__main__.Node at 0x7f610dcf39d0>,
#  'pcmcat135300050020': <__main__.Node at 0x7f610dcf3b50>,
#  'pcmcat135300050024': <__main__.Node at 0x7f610dcf3520>,
#  'pcmcat143700050011': <__main__.Node at 0x7f610dcf3c70>,
#  'pcmcat143200050028': <__main__.Node at 0x7f610dcf3a60>,
#  'pcmcat143200050027': <__main__.Node at 0x7f610dcf34f0>,
#  'pcmcat143000050020': <__main__.Node at 0x7f610dcf3e50>,
#  'pcmcat136200050016': <__main__.Node at 0x7f610dcf3370>,
#  'pcmcat143200050025': <__main__.Node at 0x7f610dcf3bb0>,
#  'pcmcat143200050024': <__main__.Node at 0x7f60cc35c0a0>,
#  'pcmcat143200050023': <__main__.Node at 0x7f60cc35c550>,
#  'pcmcat143200050022': <__main__.Node at 0x7f610dcf3940>,
#  'pcmcat143200050021': <__main__.Node at 0x7f610dcf3040>,
#  'pcmcat143200050016': <__main__.Node at 0x7f610dcf3880>,
#  'pcmcat136800050058': <__main__.Node at 0x7f610dcf3850>,
#  'pcmcat143200050026': <__main__.Node at 0x7f610dcf38e0>,
#  'pcmcat155100050037': <__main__.Node at 0x7f610dcf33a0>,
#  'pcmcat155300050007': <__main__.Node at 0x7f610dcf3280>,
#  'pcmcat155600050003': <__main__.Node at 0x7f610dcf3a00>,
#  'pcmcat184400050020': <__main__.Node at 0x7f610dcf3310>,
#  'pcmcat184000050010': <__main__.Node at 0x7f60da9fc1f0>,
#  'pcmcat184000050009': <__main__.Node at 0x7f60da9fcd30>,
#  'pcmcat184000050001': <__main__.Node at 0x7f60da9fc070>,
#  'pcmcat183800050003': <__main__.Node at 0x7f60da9fc8b0>,
#  'pcmcat183700050003': <__main__.Node at 0x7f60da9fc370>,
#  'pcmcat183200050011': <__main__.Node at 0x7f60da9fcd00>,
#  'pcmcat185200050009': <__main__.Node at 0x7f60da9fcbb0>,
#  'pcmcat181800050004': <__main__.Node at 0x7f60da9fc100>,
#  'pcmcat180700050000': <__main__.Node at 0x7f60da9fc5e0>,
#  'pcmcat180300050007': <__main__.Node at 0x7f60da9fc610>,
#  'pcmcat180100050007': <__main__.Node at 0x7f60da9fc550>,
#  'pcmcat179100050006': <__main__.Node at 0x7f60da9fcb20>,
#  'pcmcat178400050028': <__main__.Node at 0x7f60da9fc820>,
#  'pcmcat177200050009': <__main__.Node at 0x7f60da9fc3d0>,
#  'pcmcat175700050012': <__main__.Node at 0x7f60da9fcb80>,
#  'pcmcat181500050017': <__main__.Node at 0x7f60da9fc4c0>,
#  'pcmcat175500050004': <__main__.Node at 0x7f60da9fc910>,
#  'pcmcat186000050007': <__main__.Node at 0x7f60da9fca60>,
#  'pcmcat186200050012': <__main__.Node at 0x7f60da9fc490>,
#  'pcmcat223300050025': <__main__.Node at 0x7f60da9fc190>,
#  'pcmcat193100050003': <__main__.Node at 0x7f60da9fccd0>,
#  'pcmcat192700050008': <__main__.Node at 0x7f60da9fc700>,
#  'pcmcat192300050018': <__main__.Node at 0x7f60da9fc0a0>,
#  'pcmcat192000050002': <__main__.Node at 0x7f60da9fc280>,
#  'pcmcat191600050011': <__main__.Node at 0x7f60da9fca90>,
#  'pcmcat252900050012': <__main__.Node at 0x7f60da9fc160>,
#  'pcmcat186200050003': <__main__.Node at 0x7f60cc7e99d0>,
#  'pcmcat190800050003': <__main__.Node at 0x7f60cc7e9160>,
#  'pcmcat190000050006': <__main__.Node at 0x7f60da8f1f40>,
#  'pcmcat189200050005': <__main__.Node at 0x7f60cd135ca0>,
#  'pcmcat188800050003': <__main__.Node at 0x7f60da9fcac0>,
#  'pcmcat188200050000': <__main__.Node at 0x7f60da9fc850>,
#  'pcmcat187300050021': <__main__.Node at 0x7f60da9fc1c0>,
#  'pcmcat186700050011': <__main__.Node at 0x7f60da9fc7f0>,
#  'pcmcat186500050003': <__main__.Node at 0x7f610e2ad310>,
#  'pcmcat190000050016': <__main__.Node at 0x7f610e2ada00>,
#  'pcmcat175400050004': <__main__.Node at 0x7f60ccf05670>,
#  'pcmcat175100050000': <__main__.Node at 0x7f60ccf05e50>,
#  'pcmcat171100050004': <__main__.Node at 0x7f610dd2b730>,
#  'pcmcat159400050012': <__main__.Node at 0x7f60da9fcc40>,
#  'pcmcat243800050005': <__main__.Node at 0x7f60da9fce20>,
#  'pcmcat159400050006': <__main__.Node at 0x7f60da9fc580>,
#  'pcmcat158900050008': <__main__.Node at 0x7f60da9fca30>,
#  'pcmcat158600050000': <__main__.Node at 0x7f610e104b80>,
#  'pcmcat158500050029': <__main__.Node at 0x7f610e1045e0>,
#  'pcmcat157500050005': <__main__.Node at 0x7f610e104d60>,
#  'pcmcat159400050013': <__main__.Node at 0x7f610e1045b0>,
#  'pcmcat157300050001': <__main__.Node at 0x7f60da8247c0>,
#  'pcmcat156900050006': <__main__.Node at 0x7f60da8244c0>,
#  'pcmcat156600050000': <__main__.Node at 0x7f60da8245e0>,
#  'pcmcat156500050009': <__main__.Node at 0x7f60da824eb0>,
#  'pcmcat156400050037': <__main__.Node at 0x7f60da824c10>,
#  'cat15063': <__main__.Node at 0x7f60da824040>,
#  'pcmcat156300050002': <__main__.Node at 0x7f60da824310>,
#  'pcmcat155800050048': <__main__.Node at 0x7f60da824460>,
#  'pcmcat157100050023': <__main__.Node at 0x7f60da824580>,
#  'pcmcat159800050007': <__main__.Node at 0x7f60da824940>,
#  'pcmcat161100050004': <__main__.Node at 0x7f60da824dc0>,
#  'pcmcat161100050046': <__main__.Node at 0x7f60da824fd0>,
#  'pcmcat169000050018': <__main__.Node at 0x7f60da824af0>,
#  'pcmcat168900050013': <__main__.Node at 0x7f60da824790>,
#  'pcmcat166800050087': <__main__.Node at 0x7f60da824f10>,
#  'pcmcat166700050022': <__main__.Node at 0x7f60da824190>,
#  'pcmcat166600050107': <__main__.Node at 0x7f60da8246a0>,
#  'pcmcat166100050016': <__main__.Node at 0x7f60da824c40>,
#  'pcmcat165900050004': <__main__.Node at 0x7f60da824070>,
#  'pcmcat165700050000': <__main__.Node at 0x7f60da824220>,
#  'pcmcat165400050004': <__main__.Node at 0x7f60da824c70>,
#  'pcmcat164200050014': <__main__.Node at 0x7f60da824100>,
#  'pcmcat163800050029': <__main__.Node at 0x7f60da824820>,
#  'pcmcat163600050056': <__main__.Node at 0x7f60cd165250>,
#  'pcmcat163500050008': <__main__.Node at 0x7f60cd165e80>,
#  'pcmcat163200050005': <__main__.Node at 0x7f60cd165190>,
#  'pcmcat163100050004': <__main__.Node at 0x7f60cd165b80>,
#  'pcmcat162500050026': <__main__.Node at 0x7f60cd165a30>,
#  'pcmcat161500050000': <__main__.Node at 0x7f60cd165ca0>,
#  'pcmcat195200050007': <__main__.Node at 0x7f60cd165a60>,
#  'pcmcat253000050001': <__main__.Node at 0x7f60cd165610>,
#  'pcmcat208900050008': <__main__.Node at 0x7f60cd165ee0>,
#  'abcat0409000': <__main__.Node at 0x7f60cd165790>,
#  'abcat0020004': <__main__.Node at 0x7f60cd165f40>,
#  'abcat0207005': <__main__.Node at 0x7f60cd1654c0>,
#  'pcmcat27200050015': <__main__.Node at 0x7f60cd165eb0>,
#  'abcat0402000': <__main__.Node at 0x7f60cd165550>,
#  'pcmcat261800050020': <__main__.Node at 0x7f60cd165370>,
#  'abcat0202000': <__main__.Node at 0x7f60cd1657f0>,
#  'pcmcat145100050000': <__main__.Node at 0x7f60cd165bb0>,
#  'abcat0913000': <__main__.Node at 0x7f60cd165820>,
#  'pcmcat68700050002': <__main__.Node at 0x7f60cd1653a0>,
#  'abcat0410000': <__main__.Node at 0x7f60cd165970>,
#  'pcmcat267600050026': <__main__.Node at 0x7f60cd165910>,
#  'pcmcat254000050002': <__main__.Node at 0x7f60cd165c10>,
#  'pcmcat278000050000': <__main__.Node at 0x7f60cd165f10>,
#  'pcmcat208400050005': <__main__.Node at 0x7f610e5ce880>,
#  'pcmcat253300050003': <__main__.Node at 0x7f610e5ce340>,
#  'abcat0201000': <__main__.Node at 0x7f610e5ce400>,
#  'abcat0306000': <__main__.Node at 0x7f610e5ce8b0>,
#  'abcat0401005': <__main__.Node at 0x7f610e5cea90>,
#  'pcmcat258400050039': <__main__.Node at 0x7f610e5cef40>,
#  'abcat0408000': <__main__.Node at 0x7f610e5ce3a0>,
#  'abcat0302038': <__main__.Node at 0x7f610e5ce070>,
#  'pcmcat275000050000': <__main__.Node at 0x7f610e5ce760>,
#  'abcat0407000': <__main__.Node at 0x7f610e5ce550>,
#  'pcmcat257000050001': <__main__.Node at 0x7f610e5cedf0>,
#  'pcmcat159400050007': <__main__.Node at 0x7f610e5d1d30>,
#  'abcat0302000': <__main__.Node at 0x7f610e5d18e0>,
#  'abcat0102000': <__main__.Node at 0x7f610e5d1400>,
#  'pcmcat275600050000': <__main__.Node at 0x7f610e5ce850>,
#  'abcat0307000': <__main__.Node at 0x7f610e5ce940>,
#  'pcmcat269700050002': <__main__.Node at 0x7f610e5ce700>,
#  'abcat0406000': <__main__.Node at 0x7f610e5ce460>,
#  'abcat0204000': <__main__.Node at 0x7f610e5ce820>,
#  'abcat0106000': <__main__.Node at 0x7f610e5ce910>,
#  'pcmcat28300050012': <__main__.Node at 0x7f610e5cea00>,
#  'pcmcat4300050072': <__main__.Node at 0x7f610e5ce040>,
#  'pcmcat159400050014': <__main__.Node at 0x7f60ccfd3f40>,
#  'pcmcat256700050006': <__main__.Node at 0x7f60ccfd3be0>,
#  'abcat0101000': <__main__.Node at 0x7f60ccfd38e0>,
#  'abcat0020006': <__main__.Node at 0x7f60ccfd3970>,
#  'pcmcat241600050001': <__main__.Node at 0x7f60ccfd3a90>,
#  'pcmcat260500050000': <__main__.Node at 0x7f60ccfd3f70>,
#  'abcat0403000': <__main__.Node at 0x7f60ccfd3a60>,
#  'pcmcat256100050019': <__main__.Node at 0x7f60ccfd3700>,
#  'abcat0915000': <__main__.Node at 0x7f60ccfd3730>,
#  'pcmcat273800050036': <__main__.Node at 0x7f60ccfd3af0>,
#  'pcmcat255100050015': <__main__.Node at 0x7f60ccfd3760>,
#  'abcat0208000': <__main__.Node at 0x7f60ccfd3fd0>,
#  'pcmcat84000050000': <__main__.Node at 0x7f60ccfd3df0>,
#  'pcmcat84000050001': <__main__.Node at 0x7f60ccfd3190>,
#  'pcmcat84000050002': <__main__.Node at 0x7f60ccfd3b80>,
#  'abcat0012000': <__main__.Node at 0x7f60ccfd3550>,
#  'pcmcat84000050004': <__main__.Node at 0x7f60ccfd35e0>,
#  'abcat0401000': <__main__.Node at 0x7f60ccfd31c0>,
#  'abcat0301000': <__main__.Node at 0x7f60ccfd3910>,
#  'abcat0104000': <__main__.Node at 0x7f60ccfd3820>,
#  'pcmcat94300050028': <__main__.Node at 0x7f60ccfd37c0>,
#  'pcmcat253700050028': <__main__.Node at 0x7f60cc446790>,
#  'abcat0410018': <__main__.Node at 0x7f60cc4461f0>,
#  'pcmcat261800050001': <__main__.Node at 0x7f60cc446f10>,
#  'abcat0103000': <__main__.Node at 0x7f60cc446430>,
#  'abcat0304000': <__main__.Node at 0x7f60cc446340>,
#  'pcmcat271000050001': <__main__.Node at 0x7f60cc446df0>,
#  'abcat0305000': <__main__.Node at 0x7f60cc446ac0>,
#  'abcat0303000': <__main__.Node at 0x7f60cc446f70>,
#  'abcat0011000': <__main__.Node at 0x7f60cc4466a0>,
#  'abcat0201007': <__main__.Node at 0x7f60cc4464c0>,
#  'abcat0013000': <__main__.Node at 0x7f60cc4463a0>,
#  'pcmcat253800050019': <__main__.Node at 0x7f60cc446310>,
#  'pcmcat257200050005': <__main__.Node at 0x7f60cc446580>,
#  'abcat0203000': <__main__.Node at 0x7f60cc446700>,
#  'pcmcat156300050006': <__main__.Node at 0x7f60cc446d30>,
#  'pcmcat273900050010': <__main__.Node at 0x7f60cc446d60>,
#  'abcat0811002': <__main__.Node at 0x7f60cc4467f0>,
#  'abcat0201005': <__main__.Node at 0x7f60cc446070>,
#  'pcmcat255700050013': <__main__.Node at 0x7f60cc446a90>,
#  'abcat0206000': <__main__.Node at 0x7f60cc446370>,
#  'pcmcat261800050015': <__main__.Node at 0x7f60cc446040>,
#  'abcat0014000': <__main__.Node at 0x7f60cc446eb0>,
#  'abcat0107000': <__main__.Node at 0x7f60cc446c40>,
#  'abcat0605000': <__main__.Node at 0x7f60cc4469d0>,
#  'pcmcat275600050012': <__main__.Node at 0x7f60cc446490>,
#  'pcmcat249700050006': <__main__.Node at 0x7f60cc446a60>,
#  'abcat0105000': <__main__.Node at 0x7f60cc73ff70>,
#  'pcmcat165900050005': <__main__.Node at 0x7f60cc4462b0>,
#  'pcmcat165900050006': <__main__.Node at 0x7f60cc446400>,
#  'pcmcat165800050033': <__main__.Node at 0x7f60cc446af0>,
#  'pcmcat165900050007': <__main__.Node at 0x7f60cc446e50>,
#  'pcmcat165900050009': <__main__.Node at 0x7f60cc446550>,
#  'pcmcat273800050019': <__main__.Node at 0x7f60cc446b80>,
#  'pcmcat165900050008': <__main__.Node at 0x7f60cc446250>,
#  'pcmcat273800050020': <__main__.Node at 0x7f60cc446520>,
#  'pcmcat165900050010': <__main__.Node at 0x7f60cc446730>,
#  'pcmcat253600050028': <__main__.Node at 0x7f60ccf2ae50>,
#  'pcmcat165900050023': <__main__.Node at 0x7f60ccf2a460>,
#  'pcmcat168900050023': <__main__.Node at 0x7f60ccf2a520>,
#  'pcmcat168900050019': <__main__.Node at 0x7f60ccf2a130>,
#  'pcmcat168900050018': <__main__.Node at 0x7f60ccf2aee0>,
#  'pcmcat168900050016': <__main__.Node at 0x7f60ccf2a370>,
#  'pcmcat168900050015': <__main__.Node at 0x7f60ccf2a430>,
#  'pcmcat272800050027': <__main__.Node at 0x7f60ccf2a160>,
#  'pcmcat168700050023': <__main__.Node at 0x7f60ccf2af70>,
#  'pcmcat168700050019': <__main__.Node at 0x7f60ccf2a280>,
#  'pcmcat168700050018': <__main__.Node at 0x7f60ccf2a640>,
#  'pcmcat168400050038': <__main__.Node at 0x7f60ccf2afd0>,
#  'pcmcat168200050004': <__main__.Node at 0x7f60ccf2a400>,
#  'pcmcat168200050000': <__main__.Node at 0x7f60ccf2a340>,
#  'pcmcat168100050018': <__main__.Node at 0x7f60ccf2aeb0>,
#  'pcmcat165900050020': <__main__.Node at 0x7f60ccf2a100>,
#  'pcmcat168100050017': <__main__.Node at 0x7f60ccf2a550>,
#  'pcmcat168000050060': <__main__.Node at 0x7f60ccf2a070>,
#  'pcmcat168000050041': <__main__.Node at 0x7f60ccf2a3a0>,
#  'pcmcat168000050031': <__main__.Node at 0x7f60ccf14580>,
#  'pcmcat167300050040': <__main__.Node at 0x7f60ccf14c10>,
#  'pcmcat273700050009': <__main__.Node at 0x7f60ccf144f0>,
#  'pcmcat273800050002': <__main__.Node at 0x7f60ccf148e0>,
#  'pcmcat166200050003': <__main__.Node at 0x7f60ccf14b20>,
#  'pcmcat166200050002': <__main__.Node at 0x7f60ccf14070>,
#  'pcmcat166200050001': <__main__.Node at 0x7f60ccf14b80>,
#  'pcmcat166200050000': <__main__.Node at 0x7f60ccf148b0>,
#  'pcmcat166100050020': <__main__.Node at 0x7f60ccf14d30>,
#  'pcmcat273800050018': <__main__.Node at 0x7f60ccf14f40>,
#  'pcmcat166000050027': <__main__.Node at 0x7f60ccf14c40>,
#  'pcmcat168100050016': <__main__.Node at 0x7f60ccf144c0>,
#  'pcmcat273800050021': <__main__.Node at 0x7f60ccf14dc0>,
#  'pcmcat163400050000': <__main__.Node at 0x7f60ccf14ee0>,
#  'pcmcat165100050011': <__main__.Node at 0x7f60ccf14640>,
#  'pcmcat159400050011': <__main__.Node at 0x7f60ccf14760>,
#  'pcmcat274000050027': <__main__.Node at 0x7f60cd0986a0>,
#  'pcmcat159400050015': <__main__.Node at 0x7f60cd0985e0>,
#  'pcmcat159400050016': <__main__.Node at 0x7f60cd0987f0>,
#  'pcmcat159400050017': <__main__.Node at 0x7f60cd098f70>,
#  'pcmcat159400050018': <__main__.Node at 0x7f60cd098370>,
#  'pcmcat159700050051': <__main__.Node at 0x7f60cd0983d0>,
#  'pcmcat273800050035': <__main__.Node at 0x7f60cd098fa0>,
#  'pcmcat159800050008': <__main__.Node at 0x7f60cd098790>,
#  'pcmcat159800050009': <__main__.Node at 0x7f60cd098e50>,
#  'pcmcat159800050010': <__main__.Node at 0x7f60cd098d30>,
#  'pcmcat159800050011': <__main__.Node at 0x7f60cd098610>,
#  'pcmcat165800050028': <__main__.Node at 0x7f60cd098520>,
#  'pcmcat160500050018': <__main__.Node at 0x7f60cd098fd0>,
#  'pcmcat273800050033': <__main__.Node at 0x7f60cd0983a0>,
#  'pcmcat159400050010': <__main__.Node at 0x7f60cd098b20>,
#  'pcmcat159400050008': <__main__.Node at 0x7f60cd0985b0>,
#  'pcmcat274200050002': <__main__.Node at 0x7f60cd098190>,
#  'pcmcat274200050005': <__main__.Node at 0x7f60cd0981f0>,
#  'pcmcat274500050022': <__main__.Node at 0x7f60cd098820>,
#  'pcmcat158500050031': <__main__.Node at 0x7f60cd098880>,
#  'pcmcat158500050032': <__main__.Node at 0x7f60cd0989d0>,
#  'pcmcat158500050033': <__main__.Node at 0x7f60cd098220>,
#  'pcmcat158500050034': <__main__.Node at 0x7f60cd098df0>,
#  'pcmcat158500050035': <__main__.Node at 0x7f60cd0988e0>,
#  'pcmcat158500050036': <__main__.Node at 0x7f60cd098a00>,
#  'pcmcat161100050039': <__main__.Node at 0x7f60cd098280>,
#  'pcmcat158500050037': <__main__.Node at 0x7f60cd0986d0>,
#  'pcmcat274200050011': <__main__.Node at 0x7f60cd0981c0>,
#  'pcmcat158600050017': <__main__.Node at 0x7f60cd098730>,
#  'pcmcat158600050018': <__main__.Node at 0x7f60cd098970>,
#  'pcmcat158600050019': <__main__.Node at 0x7f60cd0988b0>,
#  'pcmcat274200050008': <__main__.Node at 0x7f60cd098550>,
#  'pcmcat158900050018': <__main__.Node at 0x7f60cd098ca0>,
#  'pcmcat204200050023': <__main__.Node at 0x7f610e0be100>,
#  'pcmcat158500050038': <__main__.Node at 0x7f610e0be2e0>,
#  'pcmcat273800050032': <__main__.Node at 0x7f610e0be280>,
#  'pcmcat161100050047': <__main__.Node at 0x7f610e0be070>,
#  'pcmcat161100050048': <__main__.Node at 0x7f610e0be2b0>,
#  'pcmcat273800050026': <__main__.Node at 0x7f610e0be490>,
#  'pcmcat163500050009': <__main__.Node at 0x7f610e0be0d0>,
#  'pcmcat273800050025': <__main__.Node at 0x7f610e0be130>,
#  'pcmcat163600050057': <__main__.Node at 0x7f610e0be370>,
#  'pcmcat163600050058': <__main__.Node at 0x7f610e0be040>,
#  'pcmcat163600050059': <__main__.Node at 0x7f610e0be3a0>,
#  'pcmcat273800050024': <__main__.Node at 0x7f60c1288fd0>,
#  'pcmcat273800050027': <__main__.Node at 0x7f60c1288580>,
#  'pcmcat164200050004': <__main__.Node at 0x7f60c1288a60>,
#  'pcmcat164200050015': <__main__.Node at 0x7f60c1288d30>,
#  'pcmcat164200050016': <__main__.Node at 0x7f60c1288df0>,
#  'pcmcat164200050017': <__main__.Node at 0x7f60c1288070>,
#  'pcmcat164200050018': <__main__.Node at 0x7f60c12881c0>,
#  'pcmcat164200050019': <__main__.Node at 0x7f60c1288c70>,
#  'pcmcat273800050022': <__main__.Node at 0x7f60c1288bb0>,
#  'pcmcat164800050018': <__main__.Node at 0x7f60c1288250>,
#  'pcmcat273800050023': <__main__.Node at 0x7f60c1288490>,
#  'pcmcat165100050012': <__main__.Node at 0x7f60c1288130>,
#  'pcmcat273800050029': <__main__.Node at 0x7f60c1288280>,
#  'pcmcat162700050012': <__main__.Node at 0x7f60c1288340>,
#  'pcmcat161100050049': <__main__.Node at 0x7f60c1288520>,
#  'pcmcat161100050050': <__main__.Node at 0x7f60c1288b80>,
#  'pcmcat161300050000': <__main__.Node at 0x7f60c1288100>,
#  'pcmcat161300050001': <__main__.Node at 0x7f60c1288550>,
#  'pcmcat161300050002': <__main__.Node at 0x7f60c1288eb0>,
#  'pcmcat161300050013': <__main__.Node at 0x7f60c1288ac0>,
#  'pcmcat273800050031': <__main__.Node at 0x7f60c1288670>,
#  'pcmcat162700050013': <__main__.Node at 0x7f60c1288040>,
#  'pcmcat16200050000': <__main__.Node at 0x7f60c12880d0>,
#  'pcmcat162200050005': <__main__.Node at 0x7f60c1288f70>,
#  'pcmcat162200050006': <__main__.Node at 0x7f60c12884f0>,
#  'pcmcat273800050030': <__main__.Node at 0x7f60c12880a0>,
#  'pcmcat162500050028': <__main__.Node at 0x7f60c12888b0>,
#  'pcmcat162500050029': <__main__.Node at 0x7f60ccfb8ca0>,
#  'pcmcat162500050030': <__main__.Node at 0x7f60ccfb8370>,
#  'pcmcat162500050031': <__main__.Node at 0x7f60ccfb8a30>,
#  'pcmcat162100050040': <__main__.Node at 0x7f60ccfb8550>,
#  'pcmcat168900050024': <__main__.Node at 0x7f60ccfb8700>,
#  'pcmcat175100050003': <__main__.Node at 0x7f60ccfb8b50>,
#  'pcmcat272800050018': <__main__.Node at 0x7f60ccfb8460>,
#  'pcmcat184400050002': <__main__.Node at 0x7f60ccfb8340>,
#  'pcmcat184400050003': <__main__.Node at 0x7f60ccfb8610>,
#  'pcmcat184400050004': <__main__.Node at 0x7f60ccfb8c70>,
#  'pcmcat184400050021': <__main__.Node at 0x7f60ccfb8880>,
#  'pcmcat184400050022': <__main__.Node at 0x7f60ccfb87f0>,
#  'pcmcat184400050023': <__main__.Node at 0x7f60ccfb89d0>,
#  'pcmcat184400050001': <__main__.Node at 0x7f60ccfb8040>,
#  'pcmcat184500050000': <__main__.Node at 0x7f60ccfb8d90>,
#  'pcmcat184600050001': <__main__.Node at 0x7f60ccfb8280>,
#  'pcmcat184700050008': <__main__.Node at 0x7f60ccfb8970>,
#  'pcmcat184700050009': <__main__.Node at 0x7f60cc30bcd0>,
#  'pcmcat271800050001': <__main__.Node at 0x7f60cc30b820>,
#  'pcmcat185900050069': <__main__.Node at 0x7f60cc30beb0>,
#  'pcmcat271700050014': <__main__.Node at 0x7f60cc30bb50>,
#  'pcmcat184600050000': <__main__.Node at 0x7f60cc30bf70>,
#  'pcmcat186000050024': <__main__.Node at 0x7f60cc30b8e0>,
#  'pcmcat184300050010': <__main__.Node at 0x7f60cc30bbe0>,
#  'pcmcat184300050008': <__main__.Node at 0x7f60cc30b7c0>,
#  'pcmcat182300050004': <__main__.Node at 0x7f60cc30be50>,
#  'pcmcat183200050012': <__main__.Node at 0x7f60cc30bfa0>,
#  'pcmcat183200050014': <__main__.Node at 0x7f60cc30bac0>,
#  'pcmcat183200050015': <__main__.Node at 0x7f60cc30b970>,
#  'pcmcat183500050019': <__main__.Node at 0x7f60cc30bdf0>,
#  'pcmcat272200050006': <__main__.Node at 0x7f60cc30bee0>,
#  'pcmcat184300050009': <__main__.Node at 0x7f60cc30ba60>,
#  'pcmcat27200050037': <__main__.Node at 0x7f60cc30b790>,
#  'pcmcat184000050002': <__main__.Node at 0x7f60cc30bf40>,
#  'pcmcat184000050005': <__main__.Node at 0x7f60cc30bc10>,
#  'pcmcat184000050006': <__main__.Node at 0x7f60cc412ee0>,
#  'pcmcat184000050007': <__main__.Node at 0x7f60cc4127c0>,
#  'pcmcat27200050023': <__main__.Node at 0x7f60cc412ac0>,
#  'pcmcat184000050011': <__main__.Node at 0x7f60cc4123d0>,
#  'pcmcat27200050028': <__main__.Node at 0x7f60cc412c40>,
#  'pcmcat181800050008': <__main__.Node at 0x7f60cc412df0>,
#  'pcmcat186000050025': <__main__.Node at 0x7f60cc412fa0>,
#  'pcmcat186100050007': <__main__.Node at 0x7f60cc4120d0>,
#  'pcmcat271300050013': <__main__.Node at 0x7f60cc4124c0>,
#  'pcmcat186700050024': <__main__.Node at 0x7f60cc412d60>,
#  'pcmcat186700050025': <__main__.Node at 0x7f60cc4122e0>,
#  'pcmcat186700050026': <__main__.Node at 0x7f60cc412c10>,
#  'pcmcat186800050010': <__main__.Node at 0x7f60cc412100>,
#  'pcmcat187100050006': <__main__.Node at 0x7f60cc412310>,
#  'pcmcat186600050005': <__main__.Node at 0x7f60cc412940>,
#  'pcmcat271300050012': <__main__.Node at 0x7f60cc4125b0>,
#  'pcmcat187300050023': <__main__.Node at 0x7f60cc412520>,
#  'pcmcat187300050024': <__main__.Node at 0x7f60cc412160>,
#  'pcmcat187300050025': <__main__.Node at 0x7f60cc412190>,
#  'pcmcat187400050006': <__main__.Node at 0x7f60cc412eb0>,
#  'pcmcat187400050010': <__main__.Node at 0x7f60cc412550>,
#  'pcmcat188000050000': <__main__.Node at 0x7f60cc412610>,
#  'pcmcat187300050022': <__main__.Node at 0x7f60cc412a30>,
#  'pcmcat186100050006': <__main__.Node at 0x7f60cc412bb0>,
#  'pcmcat186600050004': <__main__.Node at 0x7f60cc412790>,
#  'pcmcat186400050018': <__main__.Node at 0x7f60cc4125e0>,
#  'pcmcat271700050005': <__main__.Node at 0x7f60cc4126a0>,
#  'pcmcat186200050004': <__main__.Node at 0x7f60cc4121f0>,
#  'pcmcat186200050005': <__main__.Node at 0x7f60cc412ca0>,
#  'pcmcat186200050006': <__main__.Node at 0x7f610e0462e0>,
#  'pcmcat271300050015': <__main__.Node at 0x7f610e0460d0>,
#  'pcmcat186200050015': <__main__.Node at 0x7f610e046160>,
#  'pcmcat271300050014': <__main__.Node at 0x7f610e046310>,
#  'pcmcat186200050016': <__main__.Node at 0x7f610e0460a0>,
#  'pcmcat186400050003': <__main__.Node at 0x7f610e046250>,
#  'pcmcat186400050004': <__main__.Node at 0x7f610e046070>,
#  'pcmcat186400050010': <__main__.Node at 0x7f610e046670>,
#  'pcmcat186400050011': <__main__.Node at 0x7f610e046550>,
#  'pcmcat186400050015': <__main__.Node at 0x7f610e046100>,
#  'pcmcat186400050016': <__main__.Node at 0x7f610e0463d0>,
#  'pcmcat186200050017': <__main__.Node at 0x7f610e0466d0>,
#  'pcmcat169000050017': <__main__.Node at 0x7f610e046490>,
#  'pcmcat181800050007': <__main__.Node at 0x7f610e0464f0>,
#  'pcmcat181800050005': <__main__.Node at 0x7f610e046190>,
#  'pcmcat175000050008': <__main__.Node at 0x7f610e0466a0>,
#  'pcmcat175100050001': <__main__.Node at 0x7f610e046790>,
#  'pcmcat158500050014': <__main__.Node at 0x7f610e0465e0>,
#  'pcmcat175100050004': <__main__.Node at 0x7f610e046850>,
#  'pcmcat175100050005': <__main__.Node at 0x7f610e046970>,
#  'pcmcat175100050006': <__main__.Node at 0x7f610e0468b0>,
#  'pcmcat175000050004': <__main__.Node at 0x7f610e0462b0>,
#  'pcmcat175100050007': <__main__.Node at 0x7f610e046730>,
#  'pcmcat175100050009': <__main__.Node at 0x7f610e0468e0>,
#  'pcmcat272800050011': <__main__.Node at 0x7f610e046340>,
#  'pcmcat175400050005': <__main__.Node at 0x7f610e046bb0>,
#  'pcmcat175400050006': <__main__.Node at 0x7f610e046af0>,
#  'pcmcat175400050007': <__main__.Node at 0x7f610e0469d0>,
#  'pcmcat175400050009': <__main__.Node at 0x7f610e046580>,
#  'pcmcat175100050008': <__main__.Node at 0x7f610e046c10>,
#  'pcmcat175400050010': <__main__.Node at 0x7f610e046cd0>,
#  'pcmcat175000050003': <__main__.Node at 0x7f610e046ca0>,
#  'pcmcat175000050000': <__main__.Node at 0x7f610e046940>,
#  'pcmcat169000050023': <__main__.Node at 0x7f610e046b20>,
#  'pcmcat169000050024': <__main__.Node at 0x7f610e046f10>,
#  'pcmcat169000050025': <__main__.Node at 0x7f610e046b50>,
#  'pcmcat169900050005': <__main__.Node at 0x7f610e046e20>,
#  'pcmcat169900050006': <__main__.Node at 0x7f610e046d00>,
#  'pcmcat204200050021': <__main__.Node at 0x7f610e046ee0>,
#  'pcmcat268400050010': <__main__.Node at 0x7f610e046e50>,
#  'pcmcat171900050007': <__main__.Node at 0x7f610e046fd0>,
#  'pcmcat171900050031': <__main__.Node at 0x7f610e046e80>,
#  'pcmcat172000050000': <__main__.Node at 0x7f610dcf83d0>,
#  'pcmcat172600050005': <__main__.Node at 0x7f610dcf83a0>,
#  'pcmcat173500050009': <__main__.Node at 0x7f610dcf8220>,
#  'pcmcat174700050005': <__main__.Node at 0x7f610dcf8130>,
#  'pcmcat174800050000': <__main__.Node at 0x7f610dcf8070>,
#  'pcmcat171900050028': <__main__.Node at 0x7f610dcf85b0>,
#  'pcmcat181800050006': <__main__.Node at 0x7f610dcf84f0>,
#  'pcmcat272500050028': <__main__.Node at 0x7f610dcf8340>,
#  'pcmcat272500050022': <__main__.Node at 0x7f610dcf8190>,
#  'pcmcat180100050009': <__main__.Node at 0x7f610dcf8370>,
#  'pcmcat180100050010': <__main__.Node at 0x7f610dcf82e0>,
#  'pcmcat180100050011': <__main__.Node at 0x7f610dcf87f0>,
#  'pcmcat272500050019': <__main__.Node at 0x7f610dcf8670>,
#  'pcmcat180300050008': <__main__.Node at 0x7f610dcf8250>,
#  'pcmcat180300050009': <__main__.Node at 0x7f610dcf8280>,
#  'pcmcat180100050008': <__main__.Node at 0x7f610dcf81c0>,
#  'pcmcat180300050010': <__main__.Node at 0x7f610dcf8610>,
#  'pcmcat180300050012': <__main__.Node at 0x7f610dcf8760>,
#  'pcmcat180400050000': <__main__.Node at 0x7f610dcf8a00>,
#  'pcmcat180400050006': <__main__.Node at 0x7f610dcf8820>,
#  'pcmcat272500050018': <__main__.Node at 0x7f610dcf8520>,
#  'pcmcat180700050010': <__main__.Node at 0x7f610dcf85e0>,
#  'pcmcat272500050017': <__main__.Node at 0x7f610dcf89d0>,
#  'pcmcat180300050011': <__main__.Node at 0x7f610dcf8640>,
#  'pcmcat175600050011': <__main__.Node at 0x7f610dcf8c40>,
#  'pcmcat180000050013': <__main__.Node at 0x7f610dcf88e0>,
#  'pcmcat179200050017': <__main__.Node at 0x7f610dcf8d90>,
#  'pcmcat177200050010': <__main__.Node at 0x7f610dcf8b80>,
#  'pcmcat177200050011': <__main__.Node at 0x7f610dcf8ca0>,
#  'pcmcat177200050012': <__main__.Node at 0x7f610dcf8940>,
#  'pcmcat177200050013': <__main__.Node at 0x7f610dcf8bb0>,
#  'pcmcat177400050006': <__main__.Node at 0x7f610dcf8cd0>,
#  'pcmcat177800050029': <__main__.Node at 0x7f610dcf8970>,
#  'pcmcat179200050018': <__main__.Node at 0x7f610dcf8f10>,
#  'pcmcat177900050031': <__main__.Node at 0x7f610dcf8ac0>,
#  'pcmcat178600050003': <__main__.Node at 0x7f610dcf8e80>,
#  'pcmcat272500050020': <__main__.Node at 0x7f610dcf8be0>,
#  'pcmcat179200050003': <__main__.Node at 0x7f610dcf8e20>,
#  'pcmcat179200050008': <__main__.Node at 0x7f610dcf8fa0>,
#  'pcmcat179200050010': <__main__.Node at 0x7f610dcf8d60>,
#  'pcmcat179200050014': <__main__.Node at 0x7f610dcf8a90>,
#  'pcmcat272500050021': <__main__.Node at 0x7f610dcf8f40>,
#  'pcmcat158400050073': <__main__.Node at 0x7f60cc3c4340>,
#  'pcmcat156800050037': <__main__.Node at 0x7f60cc3c4220>,
#  'pcmcat274500050025': <__main__.Node at 0x7f60cc3c4160>,
#  'pcmcat148900050023': <__main__.Node at 0x7f60cc3c40a0>,
#  'pcmcat148900050024': <__main__.Node at 0x7f60cc3c4100>,
#  'pcmcat148900050025': <__main__.Node at 0x7f60cc3c4190>,
#  'pcmcat148900050026': <__main__.Node at 0x7f60cc3c42e0>,
#  'pcmcat148900050027': <__main__.Node at 0x7f60cc3c4280>,
#  'pcmcat148900050028': <__main__.Node at 0x7f60cc3c4430>,
#  'pcmcat148400050054': <__main__.Node at 0x7f60cc3c44f0>,
#  'pcmcat278000050004': <__main__.Node at 0x7f60cc3c42b0>,
#  'pcmcat149600050188': <__main__.Node at 0x7f60cc3c4550>,
#  'pcmcat149600050189': <__main__.Node at 0x7f60cc3c45b0>,
#  'pcmcat149600050190': <__main__.Node at 0x7f60cc3c4610>,
#  'pcmcat278000050002': <__main__.Node at 0x7f60cc3c4670>,
#  'pcmcat149900050042': <__main__.Node at 0x7f60cc3c46d0>,
#  'pcmcat216400050014': <__main__.Node at 0x7f60cc3c4730>,
#  'pcmcat278000050003': <__main__.Node at 0x7f60cc3c4790>,
#  'pcmcat150700050002': <__main__.Node at 0x7f60cc3c47f0>,
#  'pcmcat148400050053': <__main__.Node at 0x7f60cc3c4850>,
#  'pcmcat146100050019': <__main__.Node at 0x7f60cc3c48b0>,
#  'pcmcat143700050051': <__main__.Node at 0x7f60cc3c4910>,
#  'pcmcat278100050008': <__main__.Node at 0x7f60cc3c4970>,
#  'pcmcat14400050027': <__main__.Node at 0x7f60cc3c49d0>,
#  'pcmcat14400050028': <__main__.Node at 0x7f60cc3c4a30>,
#  'pcmcat14400050029': <__main__.Node at 0x7f60cc3c4a90>,
#  'pcmcat14400050030': <__main__.Node at 0x7f60cc3c4af0>,
#  'pcmcat278100050001': <__main__.Node at 0x7f60cc3c4b50>,
#  'pcmcat144700050004': <__main__.Node at 0x7f60cc3c4b20>,
#  'pcmcat145500050037': <__main__.Node at 0x7f60cc3c4c10>,
#  'pcmcat145500050038': <__main__.Node at 0x7f60cc3c4370>,
#  'pcmcat145500050039': <__main__.Node at 0x7f60cc3c4d30>,
#  'pcmcat145500050041': <__main__.Node at 0x7f60cc3c4e50>,
#  'pcmcat145500050042': <__main__.Node at 0x7f60cc3c4d90>,
#  'pcmcat146100050018': <__main__.Node at 0x7f60cc3c4c70>,
#  'pcmcat278100050002': <__main__.Node at 0x7f60cc3c4df0>,
#  'pcmcat150900050000': <__main__.Node at 0x7f60cc3c4fa0>,
#  'pcmcat151000050011': <__main__.Node at 0x7f60cc3c4f70>,
#  'pcmcat151000050013': <__main__.Node at 0x7f60cc3c4fd0>,
#  'pcmcat277500050001': <__main__.Node at 0x7f60cc3c4f40>,
#  'pcmcat151600050041': <__main__.Node at 0x7f60cc3c4bb0>,
#  'pcmcat276700050004': <__main__.Node at 0x7f60cc3c4e80>,
#  'pcmcat151900050006': <__main__.Node at 0x7f60cc3c21f0>,
#  'pcmcat276700050003': <__main__.Node at 0x7f60cc3c22b0>,
#  'pcmcat151900050008': <__main__.Node at 0x7f60cc3c2190>,
#  'pcmcat151600050040': <__main__.Node at 0x7f60cc3c2370>,
#  'pcmcat151900050009': <__main__.Node at 0x7f60cc3c2070>,
#  'pcmcat151900050011': <__main__.Node at 0x7f60cc3c21c0>,
#  'pcmcat276700050002': <__main__.Node at 0x7f60cc3c2430>,
#  'pcmcat151900050012': <__main__.Node at 0x7f60cc3c24f0>,
#  'pcmcat151900050013': <__main__.Node at 0x7f60cc3c2040>,
#  'pcmcat151900050014': <__main__.Node at 0x7f60cc3c2310>,
#  'pcmcat276700050001': <__main__.Node at 0x7f60cc3c20d0>,
#  'pcmcat151900050010': <__main__.Node at 0x7f60cc3c2550>,
#  'pcmcat151600050039': <__main__.Node at 0x7f60cc3c2520>,
#  'pcmcat151600050038': <__main__.Node at 0x7f60cc3c25e0>,
#  'pcmcat277500050002': <__main__.Node at 0x7f60cc3c2490>,
#  'pcmcat151000050014': <__main__.Node at 0x7f60cc3c27f0>,
#  'pcmcat151000050015': <__main__.Node at 0x7f60cc3c2790>,
#  'pcmcat278000050001': <__main__.Node at 0x7f60cc3c28b0>,
#  'pcmcat277500050006': <__main__.Node at 0x7f60cc3c2670>,
#  'pcmcat277500050005': <__main__.Node at 0x7f60cc3c2730>,
#  'pcmcat277500050004': <__main__.Node at 0x7f60cc3c22e0>,
#  'pcmcat151600050003': <__main__.Node at 0x7f60cc3c2880>,
#  'pcmcat151600050006': <__main__.Node at 0x7f60cc3c2940>,
#  'pcmcat151600050007': <__main__.Node at 0x7f60cc3c2c70>,
#  'pcmcat151600050008': <__main__.Node at 0x7f60cc3c2610>,
#  'pcmcat277500050003': <__main__.Node at 0x7f60cc3c2970>,
#  'pcmcat151600050022': <__main__.Node at 0x7f60cc3c2b80>,
#  'pcmcat151600050024': <__main__.Node at 0x7f60cc3c29a0>,
#  'pcmcat151600050026': <__main__.Node at 0x7f60cc3c2e50>,
#  'pcmcat221400050011': <__main__.Node at 0x7f60cc3c2d90>,
#  'pcmcat143700050048': <__main__.Node at 0x7f60cc3c2d60>,
#  'pcmcat152100050011': <__main__.Node at 0x7f60cc3c2e20>,
#  'pcmcat143700050033': <__main__.Node at 0x7f60cc3c2c40>,
#  'pcmcat143700050026': <__main__.Node at 0x7f60cc3c2f10>,
#  'pcmcat140500050012': <__main__.Node at 0x7f60cc3c29d0>,
#  'pcmcat140500050013': <__main__.Node at 0x7f60cc3c2a60>,
#  'pcmcat140800050116': <__main__.Node at 0x7f60cc3c2fa0>,
#  'pcmcat140800050128': <__main__.Node at 0x7f60cc3c2b50>,
#  'pcmcat140800050131': <__main__.Node at 0x7f60cc3c2ac0>,
#  'pcmcat140800050142': <__main__.Node at 0x7f60cc3c2d30>,
#  'pcmcat68700050006': <__main__.Node at 0x7f60cc3c2dc0>,
#  'pcmcat140900050002': <__main__.Node at 0x7f60cc3c2ca0>,
#  'pcmcat68700050004': <__main__.Node at 0x7f60cc35b280>,
#  'pcmcat140900050017': <__main__.Node at 0x7f60cc35b0d0>,
#  'pcmcat140900050018': <__main__.Node at 0x7f60cc35b2e0>,
#  'pcmcat140900050019': <__main__.Node at 0x7f60cc35b2b0>,
#  'pcmcat140900050020': <__main__.Node at 0x7f60cc35b1f0>,
#  'pcmcat140900050021': <__main__.Node at 0x7f60cc35b0a0>,
#  'pcmcat68700050005': <__main__.Node at 0x7f60cc35b340>,
#  'pcmcat141200050003': <__main__.Node at 0x7f60cc35b3d0>,
#  'pcmcat140500050011': <__main__.Node at 0x7f60cc35b430>,
#  'pcmcat140100050010': <__main__.Node at 0x7f60cc35b490>,
#  'pcmcat139300050001': <__main__.Node at 0x7f60cc35b4f0>,
#  'pcmcat99000050001': <__main__.Node at 0x7f60cc35b550>,
#  'pcmcat97200050015': <__main__.Node at 0x7f60cc35b5b0>,
#  'pcmcat139900050007': <__main__.Node at 0x7f60cc35b610>,
#  'pcmcat139900050008': <__main__.Node at 0x7f60cc35b670>,
#  'pcmcat139900050009': <__main__.Node at 0x7f60cc35b6d0>,
#  'pcmcat72400050003': <__main__.Node at 0x7f60cc35b730>,
#  'pcmcat139900050011': <__main__.Node at 0x7f60cc35b790>,
#  'pcmcat140000050021': <__main__.Node at 0x7f60cc35b7f0>,
#  'pcmcat140000050022': <__main__.Node at 0x7f60cc35b850>,
#  'pcmcat140000050023': <__main__.Node at 0x7f60cc35b8b0>,
#  'pcmcat83700050012': <__main__.Node at 0x7f60cc35b910>,
#  'pcmcat80300050000': <__main__.Node at 0x7f60cc35b970>,
#  'pcmcat77000050006': <__main__.Node at 0x7f60cc35b9d0>,
#  'pcmcat158100050000': <__main__.Node at 0x7f60cc35ba30>,
#  'pcmcat68700050003': <__main__.Node at 0x7f60cc35ba90>,
#  'pcmcat61100050005': <__main__.Node at 0x7f60cc35baf0>,
#  'pcmcat142400050016': <__main__.Node at 0x7f60cc35bb50>,
#  'pcmcat143000050069': <__main__.Node at 0x7f60cc35bbb0>,
#  'pcmcat143000050070': <__main__.Node at 0x7f60cc35bc10>,
#  'pcmcat44600050013': <__main__.Node at 0x7f60cc35bc70>,
#  'pcmcat44600050011': <__main__.Node at 0x7f60cc35bcd0>,
#  'pcmcat28200050000': <__main__.Node at 0x7f60cc35bd30>,
#  'pcmcat279600050007': <__main__.Node at 0x7f60cc35bd90>,
#  'pcmcat143000050059': <__main__.Node at 0x7f60cc35bdf0>,
#  'pcmcat279600050006': <__main__.Node at 0x7f60cc35b070>,
#  'pcmcat143400050013': <__main__.Node at 0x7f60cc35b130>,
#  'pcmcat279500050008': <__main__.Node at 0x7f60cc35bf10>,
#  'pcmcat143700050017': <__main__.Node at 0x7f60cc35be80>,
#  'pcmcat143700050018': <__main__.Node at 0x7f60cc35be50>,
#  'pcmcat278600050008': <__main__.Node at 0x7f60cc35beb0>,
#  'pcmcat143700050019': <__main__.Node at 0x7f60cc35bf70>,
#  'pcmcat279500050009': <__main__.Node at 0x7f60cc35d280>,
#  'pcmcat143000050057': <__main__.Node at 0x7f60cc35d070>,
#  'pcmcat143000050053': <__main__.Node at 0x7f60cc35d2e0>,
#  'pcmcat143000050047': <__main__.Node at 0x7f60cc35d2b0>,
#  'pcmcat142400050017': <__main__.Node at 0x7f60cc35d1f0>,
#  'pcmcat142400050018': <__main__.Node at 0x7f60cc35d040>,
#  'pcmcat142400050019': <__main__.Node at 0x7f60cc35d340>,
#  'pcmcat142400050020': <__main__.Node at 0x7f60cc35d3d0>,
#  'pcmcat50000050018': <__main__.Node at 0x7f60cc35d430>,
#  'pcmcat143000050007': <__main__.Node at 0x7f60cc35d400>,
#  'pcmcat143000050009': <__main__.Node at 0x7f60cc35d460>,
#  'pcmcat143000050010': <__main__.Node at 0x7f60cc35d7f0>,
#  'pcmcat143000050011': <__main__.Node at 0x7f60cc35d130>,
#  'pcmcat59600050005': <__main__.Node at 0x7f60cc35d6a0>,
#  'pcmcat50000050009': <__main__.Node at 0x7f60cc35d4f0>,
#  'pcmcat143000050021': <__main__.Node at 0x7f60cc35d0d0>,
#  'pcmcat143000050023': <__main__.Node at 0x7f60cc35d670>,
#  'pcmcat50000050007': <__main__.Node at 0x7f60cc35d910>,
#  'pcmcat143000050041': <__main__.Node at 0x7f60cc35d550>,
#  'pcmcat143700050030': <__main__.Node at 0x7f60cc35d610>,
#  'pcmcat158400050071': <__main__.Node at 0x7f60cc35d640>,
#  'pcmcat152100050012': <__main__.Node at 0x7f60cc35d8e0>,
#  'pcmcat152100050018': <__main__.Node at 0x7f60cc35d6d0>,
#  'pcmcat155900050008': <__main__.Node at 0x7f60cc35daf0>,
#  'pcmcat155900050009': <__main__.Node at 0x7f60cc35da90>,
#  'pcmcat156100050000': <__main__.Node at 0x7f60cc35dbb0>,
#  'pcmcat275000050002': <__main__.Node at 0x7f60cc35d9d0>,
#  'pcmcat275000050001': <__main__.Node at 0x7f60cc35da30>,
#  'pcmcat156300050005': <__main__.Node at 0x7f60cc35d970>,
#  'pcmcat155900050007': <__main__.Node at 0x7f60cc35dc70>,
#  'pcmcat156500050039': <__main__.Node at 0x7f60cc35dc40>,
#  'pcmcat156300050013': <__main__.Node at 0x7f60cc35dca0>,
#  'pcmcat156300050014': <__main__.Node at 0x7f60cc35dfd0>,
#  'pcmcat274800050017': <__main__.Node at 0x7f60cc35deb0>,
#  'pcmcat274800050002': <__main__.Node at 0x7f60cc35dfa0>,
#  'pcmcat156500050010': <__main__.Node at 0x7f60cc35de50>,
#  'pcmcat156500050035': <__main__.Node at 0x7f60cc35d490>,
#  'pcmcat156300050012': <__main__.Node at 0x7f60cc35de80>,
#  'pcmcat156500050044': <__main__.Node at 0x7f60cc35dbe0>,
#  'pcmcat186400050026': <__main__.Node at 0x7f60cc35dcd0>,
#  'pcmcat155800050050': <__main__.Node at 0x7f60cc35ddf0>,
#  'pcmcat154500050009': <__main__.Node at 0x7f60cc35dd30>,
#  'pcmcat154500050014': <__main__.Node at 0x7f60cc31c2e0>,
#  'pcmcat154500050020': <__main__.Node at 0x7f60cc31c250>,
#  'pcmcat275000050006': <__main__.Node at 0x7f60cc31c220>,
#  'pcmcat155200050007': <__main__.Node at 0x7f60cc31c370>,
#  'pcmcat155200050008': <__main__.Node at 0x7f60cc31c130>,
#  'pcmcat155800050051': <__main__.Node at 0x7f60cc31c190>,
#  'pcmcat275000050005': <__main__.Node at 0x7f60cc31c3d0>,
#  'pcmcat155400050001': <__main__.Node at 0x7f60cc31c4f0>,
#  'pcmcat155400050002': <__main__.Node at 0x7f60cc31c430>,
#  'pcmcat155400050003': <__main__.Node at 0x7f60cc31c160>,
#  'pcmcat275000050004': <__main__.Node at 0x7f60cc31c310>,
#  'pcmcat275000050003': <__main__.Node at 0x7f60cc31c550>,
#  'pcmcat155800050049': <__main__.Node at 0x7f60cc31c610>,
#  'pcmcat155400050000': <__main__.Node at 0x7f60cc31c0d0>,
#  'pcmcat156500050045': <__main__.Node at 0x7f60cc31c670>,
#  'pcmcat156500050046': <__main__.Node at 0x7f60cc31c6d0>,
#  'pcmcat274600050018': <__main__.Node at 0x7f60cc31c730>,
#  'pcmcat157100050025': <__main__.Node at 0x7f60cc31c790>,
#  'pcmcat157100050026': <__main__.Node at 0x7f60cc31c7f0>,
#  'pcmcat157100050027': <__main__.Node at 0x7f60cc31c850>,
#  'pcmcat157100050028': <__main__.Node at 0x7f60cc31c8b0>,
#  'pcmcat157100050029': <__main__.Node at 0x7f60cc31c910>,
#  'pcmcat157300050002': <__main__.Node at 0x7f60cc31c970>,
#  'pcmcat157100050024': <__main__.Node at 0x7f60cc31c9d0>,
#  'pcmcat157300050003': <__main__.Node at 0x7f60cc31ca30>,
#  'pcmcat157300050005': <__main__.Node at 0x7f60cc31ca90>,
#  'pcmcat157300050028': <__main__.Node at 0x7f60cc31caf0>,
#  'pcmcat157300050029': <__main__.Node at 0x7f60cc31cb50>,
#  'pcmcat157300050030': <__main__.Node at 0x7f60cc31cbb0>,
#  'pcmcat157300050031': <__main__.Node at 0x7f60cc31cc10>,
#  'pcmcat157300050032': <__main__.Node at 0x7f60cc31cc70>,
#  'pcmcat157300050004': <__main__.Node at 0x7f60cc31ccd0>,
#  'pcmcat274600050016': <__main__.Node at 0x7f60cc31cd30>,
#  'pcmcat156900050013': <__main__.Node at 0x7f60cc31cd90>,
#  'pcmcat156900050012': <__main__.Node at 0x7f60cc31cdf0>,
#  'pcmcat156600050001': <__main__.Node at 0x7f60cc31c460>,
#  'pcmcat194000050011': <__main__.Node at 0x7f60cc31c490>,
#  'pcmcat156600050003': <__main__.Node at 0x7f60cc31cf10>,
#  'pcmcat156600050004': <__main__.Node at 0x7f60cc31ce80>,
#  'pcmcat156600050005': <__main__.Node at 0x7f60cc31ce50>,
#  'pcmcat156700050003': <__main__.Node at 0x7f60cc31ceb0>,
#  'pcmcat156800050034': <__main__.Node at 0x7f60cc31cf70>,
#  'pcmcat156800050035': <__main__.Node at 0x7f60cc318280>,
#  'pcmcat188000050002': <__main__.Node at 0x7f60cc318070>,
#  'pcmcat156800050041': <__main__.Node at 0x7f60cc3182e0>,
#  'pcmcat156800050043': <__main__.Node at 0x7f60cc3182b0>,
#  'pcmcat274600050017': <__main__.Node at 0x7f60cc3181f0>,
#  'pcmcat156900050007': <__main__.Node at 0x7f60cc318040>,
#  'pcmcat156900050009': <__main__.Node at 0x7f60cc318340>,
#  'pcmcat156900050011': <__main__.Node at 0x7f60cc3183d0>,
#  'pcmcat275100050013': <__main__.Node at 0x7f60cc318430>,
#  'pcmcat152100050013': <__main__.Node at 0x7f60cc318400>,
#  'pcmcat154400050046': <__main__.Node at 0x7f60cc3184f0>,
#  'pcmcat154400050019': <__main__.Node at 0x7f60cc3180d0>,
#  'pcmcat152100050039': <__main__.Node at 0x7f60cc3187c0>,
#  'pcmcat275600050013': <__main__.Node at 0x7f60cc318730>,
#  'pcmcat152200050007': <__main__.Node at 0x7f60cc318910>,
#  'pcmcat152200050008': <__main__.Node at 0x7f60cc3188e0>,
#  'pcmcat152200050013': <__main__.Node at 0x7f60cc3189d0>,
#  'pcmcat152200050017': <__main__.Node at 0x7f60cc3188b0>,
#  'pcmcat251600050003': <__main__.Node at 0x7f60cc318880>,
#  'pcmcat152200050018': <__main__.Node at 0x7f60cc318130>,
#  'pcmcat152600050005': <__main__.Node at 0x7f60cc3185e0>,
#  'pcmcat152600050006': <__main__.Node at 0x7f60cc318610>,
#  'pcmcat152600050007': <__main__.Node at 0x7f60cc318af0>,
#  'pcmcat152600050008': <__main__.Node at 0x7f60cc318820>,
#  'pcmcat275600050007': <__main__.Node at 0x7f60cc318a30>,
#  'pcmcat152600050014': <__main__.Node at 0x7f60cc3186d0>,
#  'pcmcat275600050008': <__main__.Node at 0x7f60cc318940>,
#  'pcmcat152600050015': <__main__.Node at 0x7f60cc318bb0>,
#  'pcmcat275600050014': <__main__.Node at 0x7f60cc318490>,
#  'pcmcat152100050031': <__main__.Node at 0x7f60cc318700>,
#  'pcmcat152100050016': <__main__.Node at 0x7f60cc318be0>,
#  'pcmcat152100050017': <__main__.Node at 0x7f60cc318f70>,
#  'pcmcat276700050000': <__main__.Node at 0x7f60cc318e50>,
#  'pcmcat275800050016': <__main__.Node at 0x7f60cc318c10>,
#  'pcmcat152100050022': <__main__.Node at 0x7f60cc318e80>,
#  'pcmcat152100050023': <__main__.Node at 0x7f60cc318fa0>,
#  'pcmcat152100050032': <__main__.Node at 0x7f60cc318c40>,
#  'pcmcat152100050024': <__main__.Node at 0x7f60cc318a90>,
#  'pcmcat253300050007': <__main__.Node at 0x7f60cc318ca0>,
#  'pcmcat275800050015': <__main__.Node at 0x7f60cc318dc0>,
#  'pcmcat275600050015': <__main__.Node at 0x7f60cc318f40>,
#  'pcmcat152100050028': <__main__.Node at 0x7f60cc318ee0>,
#  'pcmcat152100050029': <__main__.Node at 0x7f60cc319220>,
#  'pcmcat152100050030': <__main__.Node at 0x7f60cc319430>,
#  'pcmcat152100050025': <__main__.Node at 0x7f60cc319130>,
#  'pcmcat230000050019': <__main__.Node at 0x7f60cc319040>,
#  'pcmcat152800050009': <__main__.Node at 0x7f60cc3192e0>,
#  'pcmcat152800050010': <__main__.Node at 0x7f60cc319250>,
#  'pcmcat154300050002': <__main__.Node at 0x7f60cc3194f0>,
#  'pcmcat154300050003': <__main__.Node at 0x7f60cc3190d0>,
#  'pcmcat154300050004': <__main__.Node at 0x7f60cc319100>,
#  'pcmcat154300050005': <__main__.Node at 0x7f60cc319070>,
#  'pcmcat154300050006': <__main__.Node at 0x7f60cc319550>,
#  'pcmcat275100050014': <__main__.Node at 0x7f60cc3195b0>,
#  'pcmcat154200050050': <__main__.Node at 0x7f60cc3193a0>,
#  'pcmcat154300050025': <__main__.Node at 0x7f60cc319610>,
#  'pcmcat154300050027': <__main__.Node at 0x7f60cc319670>,
#  'pcmcat154300050028': <__main__.Node at 0x7f60cc3196d0>,
#  'pcmcat154300050029': <__main__.Node at 0x7f60cc319730>,
#  'pcmcat154300050030': <__main__.Node at 0x7f60cc319790>,
#  'pcmcat154400050004': <__main__.Node at 0x7f60cc3197f0>,
#  'pcmcat154400050005': <__main__.Node at 0x7f60cc319850>,
#  'pcmcat154300050026': <__main__.Node at 0x7f60cc3198b0>,
#  'pcmcat154200050029': <__main__.Node at 0x7f60cc319910>,
#  'pcmcat154200050027': <__main__.Node at 0x7f60cc319970>,
#  'pcmcat154200050025': <__main__.Node at 0x7f60cc3199d0>,
#  'pcmcat152800050011': <__main__.Node at 0x7f60cc319a30>,
#  'pcmcat152800050012': <__main__.Node at 0x7f60cc319a90>,
#  'pcmcat152800050013': <__main__.Node at 0x7f60cc319af0>,
#  'pcmcat275600050006': <__main__.Node at 0x7f60cc319b50>,
#  'pcmcat275600050005': <__main__.Node at 0x7f60cc319bb0>,
#  'pcmcat275600050004': <__main__.Node at 0x7f60cc319c10>,
#  'pcmcat275600050003': <__main__.Node at 0x7f60cc319c70>,
#  'pcmcat153200050011': <__main__.Node at 0x7f60cc319cd0>,
#  'pcmcat275600050001': <__main__.Node at 0x7f60cc319d30>,
#  'pcmcat153200050012': <__main__.Node at 0x7f60cc319d90>,
#  'pcmcat153200050013': <__main__.Node at 0x7f60cc319df0>,
#  'pcmcat153200050017': <__main__.Node at 0x7f60cc319190>,
#  'pcmcat275100050015': <__main__.Node at 0x7f60cc319460>,
#  'pcmcat153700050021': <__main__.Node at 0x7f60cc319dc0>,
#  'pcmcat154200050013': <__main__.Node at 0x7f60cc319e80>,
#  'pcmcat154400050031': <__main__.Node at 0x7f60cc319f70>,
#  'pcmcat188000050003': <__main__.Node at 0x7f60cc319f10>,
#  'pcmcat190800050007': <__main__.Node at 0x7f60cc319ee0>,
#  'pcmcat188600050033': <__main__.Node at 0x7f60cc31b2e0>,
#  'pcmcat230600050001': <__main__.Node at 0x7f60cc31b070>,
#  'pcmcat230600050002': <__main__.Node at 0x7f60cc31b160>,
#  'pcmcat230600050003': <__main__.Node at 0x7f60cc31b310>,
#  'pcmcat230600050004': <__main__.Node at 0x7f60cc31b0d0>,
#  'pcmcat230600050005': <__main__.Node at 0x7f60cc31b040>,
#  'pcmcat230800050017': <__main__.Node at 0x7f60cc31b1c0>,
#  'pcmcat257400050023': <__main__.Node at 0x7f60cc31b3d0>,
#  'pcmcat230800050019': <__main__.Node at 0x7f60cc31b6d0>,
#  'pcmcat257100050034': <__main__.Node at 0x7f60cc31b4f0>,
#  'pcmcat257100050031': <__main__.Node at 0x7f60cc31b580>,
#  'pcmcat257100050030': <__main__.Node at 0x7f60cc31b430>,
#  'pcmcat231000050008': <__main__.Node at 0x7f60cc31b400>,
#  'pcmcat231300050004': <__main__.Node at 0x7f60cc31b340>,
#  'pcmcat231700050017': <__main__.Node at 0x7f60cc31b910>,
#  'pcmcat257300050005': <__main__.Node at 0x7f60cc31b100>,
#  'pcmcat230500050000': <__main__.Node at 0x7f60cc31b460>,
#  'pcmcat230000050018': <__main__.Node at 0x7f60cc31b610>,
#  'pcmcat230000050017': <__main__.Node at 0x7f60cc31b970>,
#  'pcmcat227500050048': <__main__.Node at 0x7f60cc31b730>,
#  'pcmcat227500050049': <__main__.Node at 0x7f60cc31b850>,
#  'pcmcat227500050050': <__main__.Node at 0x7f60cc31b640>,
#  ...}
